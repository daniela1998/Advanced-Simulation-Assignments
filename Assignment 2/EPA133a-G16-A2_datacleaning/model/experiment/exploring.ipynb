# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('demo_100.csv')
df.head()
# Out:
#   road    id model_type                                               name  \
# 0   N1  N1_0     source  Start of Road  after Jatrabari Flyover infront...
# 1   N1  N1_1       link                                    Km post missing
# 2   N1  N1_2     bridge                                                  .
# 3   N1  N1_3       link                                    Km post missing
# 4   N1  N1_4       link                                    Km post missing
#
#          lat        lon  length condition
# 0  23.706028  90.443333     0.0       NaN
# 1  23.702139  90.451972     1.0       NaN
# 2  23.698739  90.458861     0.8         A
# 3  23.697889  90.460583     0.2       NaN
# 4  23.693833  90.469138     1.0       NaN

# %%
# count rows, group by road
df.groupby('road').size()
# Out:
# road
# N1       1087
# N101        8
# N102      174
# N103        7
# N104       91
#          ...
# Z8910      57
# Z8913      39
# Z8915      25
# Z8916      18
# Z8943      20
# Length: 847, dtype: int64

# %%
# group by model_type == source
source = df[df['model_type'] == 'source']
source
# Out:
#         road       id model_type  \
# 0         N1     N1_0     source
# 1087    N101   N101_0     source
# 1095    N102   N102_0     source
# 1269    N103   N103_0     source
# 1276    N104   N104_0     source
# ...      ...      ...        ...
# 38577  Z8910  Z8910_0     source
# 38634  Z8913  Z8913_0     source
# 38673  Z8915  Z8915_0     source
# 38698  Z8916  Z8916_0     source
# 38716  Z8943  Z8943_0     source
#
#                                                     name        lat  \
# 0      Start of Road  after Jatrabari Flyover infront...  23.706028
# 1087                 Start of Road from N120 at Balutopa  23.454139
# 1095                     Start of road from N1 Mainamati  23.478972
# 1269                   Road  start from N102 at Kuatali.  23.957028
# 1276                             Intersection with Z1031  23.009667
# ...                                                  ...        ...
# 38577  Start of Bairagir pool and Intersection of Z80...  22.674722
# ...

# %%
source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 847 entries, 0 to 38716
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   road        847 non-null    object
#  1   id          847 non-null    object
#  2   model_type  847 non-null    object
#  3   name        847 non-null    object
#  4   lat         847 non-null    float64
#  5   lon         847 non-null    float64
#  6   length      847 non-null    float64
#  7   condition   1 non-null      object
# dtypes: float64(3), object(5)
# memory usage: 59.6+ KB

# %%
source.describe()
# Out:
#               lat         lon  length
# count  847.000000  847.000000   847.0
# mean    23.837257   90.240598     0.0
# std      1.085372    1.031606     0.0
# min     20.862861   88.163583     0.0
# 25%     23.007736   89.383166     0.0
# 50%     23.795277   90.194889     0.0
# 75%     24.663958   90.981291     0.0
# max     26.488889   92.298222     0.0

# %%
# select road N1 
n1 = df[df['road'] == 'N1']
n1.head()
# Out:
#   road    id model_type                                               name  \
# 0   N1  N1_0     source  Start of Road  after Jatrabari Flyover infront...
# 1   N1  N1_1       link                                    Km post missing
# 2   N1  N1_2     bridge                                                  .
# 3   N1  N1_3       link                                    Km post missing
# 4   N1  N1_4       link                                    Km post missing
#
#          lat        lon  length condition
# 0  23.706028  90.443333     0.0       NaN
# 1  23.702139  90.451972     1.0       NaN
# 2  23.698739  90.458861     0.8         A
# 3  23.697889  90.460583     0.2       NaN
# 4  23.693833  90.469138     1.0       NaN

# %%
n1.tail()
# Out:
#      road       id model_type  \
# 1082   N1  N1_1082     bridge
# 1083   N1  N1_1083       link
# 1084   N1  N1_1084       link
# 1085   N1  N1_1085       link
# 1086   N1  N1_1086       sink
#
#                                                    name        lat        lon  \
# 1082                                      YAKNAT BRIDGE  20.880985  92.297777
# 1083                                        Teknaf 2 km  20.878222  92.297777
# 1084                                    Km post missing  20.869277  92.298139
# 1085                                      Infor.missing  20.862972  92.298083
# 1086  End of Road at Shapla Chattar ,Teknaf Meet wit...  20.862917  92.298083
#
#       length condition
# 1082   0.247         C
# 1083   0.313       NaN
# 1084   1.000       NaN
# 1085   0.698       NaN
# 1086   0.130       NaN

# %%
# calculate length of road N1
n1['length'].sum()
# Out:
# 462.25399999999996

# %%
n1['length'].sum()/48
# Out:
# 9.630291666666666

# %%
a = 578.0/60
b = 611/60
c = 642.8/60
d = 1115.59/60
e = 1639.187/60
f = 2226.26/60
g = 3853.47/60
h = 5630.65/60
#i = /60

print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(g)
print(h)
#print(i)
# Out:
# 9.633333333333333
# 10.183333333333334
# 10.713333333333333
# 18.593166666666665
# 27.31978333333333
# 37.10433333333334
# 64.22449999999999
# 93.84416666666667

# %%
n1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1087 entries, 0 to 1086
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   road        1087 non-null   object
#  1   id          1087 non-null   object
#  2   model_type  1087 non-null   object
#  3   name        1087 non-null   object
#  4   lat         1087 non-null   float64
#  5   lon         1087 non-null   float64
#  6   length      1087 non-null   float64
#  7   condition   628 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 76.4+ KB

# %%
n1.describe()
# Out:
#                lat          lon       length
# count  1087.000000  1087.000000  1087.000000
# mean     22.185939    91.749790     0.425257
# std       0.898472     0.504115     0.409013
# min      20.862917    90.443333     0.000000
# 25%      21.374315    91.403601     0.167500
# 50%      22.115194    92.045805     0.339000
# 75%      22.993655    92.097263     0.612500
# max      23.706028    92.299639     9.450000

# %%
# count model_type == bridge
len(n1[n1['model_type'] == 'bridge'])
# Out:
# 628

# %%
# select model_type == bridge and group by condition and count the length
n1[n1['model_type'] == 'bridge'].groupby('condition').size()
# Out:
# condition
# A    421
# B    113
# C     88
# D      6
# dtype: int64

# %%
# plot lat and lon
plt.plot(n1['lon'], n1['lat'], 'o')
# plot line between points
plt.plot(n1['lon'], n1['lat'], '-')
plt.show()
