# %% [markdown]
# # Import data

# %%
import pandas as pd

# %%
# import data
dir = 'infrastructure/original/'
filename = 'Roads_InfoAboutEachLRP.csv'
df_roadinfo = pd.read_csv(dir + filename)

# %%
# import data
dir = 'infrastructure/original/'
filename = 'BMMS_overview.xlsx'
df_bridges = pd.read_excel(dir + filename)

# %%
# import roads_transposed.csv
dir = ''
filename = 'CORRECT_ROAD_ATM.csv' # replace this with the interpolated data
df_roads = pd.read_csv(dir + filename)

# %% [markdown]
# # Clean bridge data (by Yao)

# %%
# Swap 'lat' and 'lon' if both are out of bounds

# Define latitude and longitude boundaries
LAT_MIN, LAT_MAX = 20, 28
LON_MIN, LON_MAX = 88, 93

def swap_coordinates(row):
    if not (LAT_MIN <= row['lat'] <= LAT_MAX) and not (LON_MIN <= row['lon'] <= LON_MAX):
        row['lat'], row['lon'] = row['lon'], row['lat']  # Swap values
    return row

def clean_bridge_data(df_bridges):
    # make a copy of the original data
    bridge = df_bridges.copy()

    # delete the rows with missing values in column 'lat' or 'lon'
    bridge_new = bridge.dropna(subset=['lat', 'lon'])

    # delete the rows with 0 in column 'lat' or 'lon'
    bridge_new = bridge_new[(bridge_new['lat'] != 0) & (bridge_new['lon'] != 0)]

    # create a new column 'road_LRPName' by combining 'road' and 'LRPName'
    bridge_new = bridge_new.copy()
    bridge_new['road_LRPName'] = bridge_new['road'] + '_' + bridge_new['LRPName']

    # add a column 'null_num' with the calculattion of the number of null values for the each row
    bridge_new['null_num'] = bridge_new.isnull().sum(axis=1)

    # delete the rows with duplicated 'road_LRPName' and keep the row with the minimum number of null values
    bridge_new = bridge_new.loc[bridge_new.groupby('road_LRPName')['null_num'].idxmin()]

    # find the duplicated 'road_LRPName'
    bridge_new[bridge_new.duplicated(subset='road_LRPName', keep=False)]

    # sort the data by 'road'
    #bridge_new = bridge_new.sort_values(by=['road', 'LRPName'])

    # Find the rows with 'lat' and 'lon' out of bounds
    bridge_new[(bridge_new['lat'] < LAT_MIN) |
               (bridge_new['lat'] > LAT_MAX) |
               (bridge_new['lon'] < LON_MIN) | 
               (bridge_new['lon'] > LON_MAX)]
    
    bridge_new = bridge_new.apply(swap_coordinates, axis=1)

    # Find the rows with 'lat' and 'lon' out of bounds
    bridge_new[(bridge_new['lat'] < LAT_MIN) | 
               (bridge_new['lat'] > LAT_MAX) | 
               (bridge_new['lon'] < LON_MIN) | 
               (bridge_new['lon'] > LON_MAX)]
    
    return bridge_new

# %%
cleaned_bridges = clean_bridge_data(df_bridges)
cleaned_bridges
# Out:
#         road     km                   type  LRPName                   name  \
# 1869    N102  2.059            Box Culvert  LRP002a              Brorechon
# 1870    N102  2.363            Box Culvert  LRP002b           SHABAR BAZAR
# 1871    N102  2.511            Box Culvert  LRP002c      ZUMUR BOX CULVERT
# 15844   N102  4.249           Slab Culvert  LRP004a  DEAB POR SLAB CULVERT
# 16838   N102  7.036            Box Culvert  LRP007a                 RAMPUR
# ...      ...    ...                    ...      ...                    ...
# 15394  Z8948  1.010            Box Culvert  LRP001a                      .
# 15396  Z8948  2.070  Steel Beam & RCC Slab  LRP002a                      .
# 15397  Z8948  2.100  Steel Beam & RCC Slab  LRP002c                      .
# 15392  Z8948  0.306            Box Culvert    LRPSa                      .
# 15393  Z8948  0.640            Box Culvert    LRPSb                      .
#
#        length condition  structureNr  \
# 1869     1.50         A       114920
# 1870     1.60         A       101250
# 1871     1.40         A       101252
# 15844    2.50         B       101256
# 16838    3.75         C       101262
# ...       ...       ...          ...
# 15394    2.00         A       116834
# 15396   18.50         A       116835
# 15397   18.50         A       116836
# 15392    2.00         A       116832
# 15393    2.00         A       116833
#
#                                              roadName  chainage  ...  spans  \
# 1869   Comilla (Mainamati)-Brahmanbaria (Sarail) Road     2.059  ...    1.0
# 1870   Comilla (Mainamati)-Brahmanbaria (Sarail) Road     2.363  ...    1.0
# 1871   Comilla (Mainamati)-Brahmanbaria (Sarail) Road     2.511  ...    1.0
# 15844  Comilla (Mainamati)-Brahmanbaria (Sarail) Road     4.249  ...    1.0
# 16838  Comilla (Mainamati)-Brahmanbaria (Sarail) Road     7.036  ...    1.0
# ...                                               ...       ...  ...    ...
# 15394                        Fakirhat-Khasherhat Road     1.010  ...    1.0
# 15396                        Fakirhat-Khasherhat Road     2.070  ...    3.0
# 15397                        Fakirhat-Khasherhat Road     2.100  ...    3.0
# 15392                        Fakirhat-Khasherhat Road     0.306  ...    1.0
# 15393                        Fakirhat-Khasherhat Road     0.640  ...    1.0
#
#           zone   circle division sub-division        lat        lon  \
# 1869   Comilla  Comilla  Comilla     Gouripur  23.493750  91.106472
# 1870   Comilla  Comilla  Comilla     Gouripur  23.496389  91.105944
# 1871   Comilla  Comilla  Comilla     Gouripur  23.497722  91.105639
# 15844  Comilla  Comilla  Comilla     Gouripur  23.511250  91.098194
# 16838  Comilla  Comilla  Comilla     Gouripur  23.532417  91.083528
# ...        ...      ...      ...          ...        ...        ...
# 15394  Barisal  Barisal    Bhola        Bhola  22.419167  90.787500
# 15396  Barisal  Barisal    Bhola        Bhola  22.414167  90.791667
# 15397  Barisal  Barisal    Bhola        Bhola  22.414167  90.791944
# 15392  Barisal  Barisal    Bhola        Bhola  22.425278  90.787778
# 15393  Barisal  Barisal    Bhola        Bhola  22.422778  90.787222
#
#        EstimatedLoc   road_LRPName null_num
# 1869           bcs1   N102_LRP002a        0
# 1870           bcs1   N102_LRP002b        0
# 1871           bcs1   N102_LRP002c        0
# 15844          bcs1   N102_LRP004a        0
# 16838          bcs1   N102_LRP007a        0
# ...             ...            ...      ...
# 15394          bcs1  Z8948_LRP001a        0
# 15396          bcs1  Z8948_LRP002a        0
# 15397          bcs1  Z8948_LRP002c        0
# 15392          bcs1    Z8948_LRPSa        0
# 15393          bcs1    Z8948_LRPSb        0
#
# [18323 rows x 22 columns]

# %% [markdown]
# ## Save excel file

# %%
# Save the cleaned data to a .xlsx file
dir = 'infrastructure/cleaned/'
filename = 'BMMS_overview_cleaned_prelim.xlsx'
cleaned_bridges.to_excel(dir + filename, index=False, sheet_name='BMMS_overview')

# %% [markdown]
# # Remove bridges without roads

# %%
# Create a dictionary to store the LRPE for each road
lrpe_dict = {}

# Create a dictionary to store the one LRP before LRPE for each road
lrp_before_lrpe = {}

# Iterate over each unique road
for road in df_roads['road'].unique():
    # Get the rows for the current road
    road_rows = df_roads[df_roads['road'] == road]
    
    # Find the index of LRPE
    if 'LRPE' in road_rows['lrp'].values:
        lrpe_indices = road_rows[road_rows['lrp'] == 'LRPE'].index
        if len(lrpe_indices) > 0:
            lrpe_index = lrpe_indices[0]
            lrpe_dict[road] = road_rows.loc[lrpe_index, 'lrp']
            if lrpe_index > 0 and lrpe_index - 1 < len(road_rows):
                lrp_before_lrpe[road] = road_rows.iloc[lrpe_index - 1]['lrp']
            else:
                lrp_before_lrpe[road] = road_rows.iloc[-2]['lrp']
        else:
            lrp_before_lrpe[road] = road_rows.iloc[-2]['lrp']
    else:
        # Remember the last LRP if there is no LRPE
        lrp_before_lrpe[road] = road_rows.iloc[-1]['lrp']
        lrpe_dict[road] = None  # Add a placeholder for LRPE

# Combine the dictionaries into a dataframe
df_lrpe_road = pd.DataFrame({
    'road': lrpe_dict.keys(),
    'LRP_before_E': lrp_before_lrpe.values(),
    'LRPE': lrpe_dict.values()
})

df_lrpe_road
# Out:
#       road LRP_before_E  LRPE
# 0       N1       LRP467  LRPE
# 1     N101       LRP006  LRPE
# 2     N102      LRP082a  LRPE
# 3     N103       LRP005  LRPE
# 4     N104      LRP049c  LRPE
# ..     ...          ...   ...
# 872  Z8910      LRP039b  LRPE
# 873  Z8913      LRP025a  None
# 874  Z8915       LRP016  LRPE
# 875  Z8916      LRP011b  LRPE
# 876  Z8943      LRP008b  LRPE
#
# [877 rows x 3 columns]

# %%
# Sort the dataframe by road and LRP, but keep 'LRPS' at the start and 'LRPE' in its original place
def custom_sort(df):
    df['lrp_order'] = df['LRPName'].apply(lambda x: 0 if 'LRPS' in x else 1)
    df = df.sort_values(by=['road', 'lrp_order', 'LRPName'])
    df = df.drop(columns=['lrp_order'])
    return df

cleaned_bridges_sorted = custom_sort(cleaned_bridges)

# %%
# Function to remove rows with lrp after 'LRP_before_E' for each unique road
def remove_rows_after_lrp_before_e(df, df_lrpe):
    for _, row in df_lrpe.iterrows():
        road = row['road']
        lrp_before_e = row['LRP_before_E']
        
        # Get the index of the row with 'LRP_before_E'
        lrp_before_e_index = df[(df['road'] == road) & (df['LRPName'] == lrp_before_e)].index
        
        if not lrp_before_e_index.empty:
            lrp_before_e_index = lrp_before_e_index[0]
            # Drop rows after 'LRP_before_E'
            df = df.drop(df[(df['road'] == road) & (df.index > lrp_before_e_index)].index)
    
    return df

# Apply the function to df_roads_bridges_combined_sorted
df_bridges_no_lrp_after_e = remove_rows_after_lrp_before_e(cleaned_bridges_sorted, df_lrpe_road)
df_bridges_no_lrp_after_e
# Out:
#         road      km                   type  LRPName  \
# 0         N1   1.800            Box Culvert  LRP001a
# 1         N1   4.925            Box Culvert  LRP004b
# 13420     N1   8.976       PC Girder Bridge  LRP008b
# 15398     N1  10.543            Box Culvert  LRP010a
# 3         N1  10.880            Box Culvert  LRP010b
# ...      ...     ...                    ...      ...
# 15392  Z8948   0.306            Box Culvert    LRPSa
# 15393  Z8948   0.640            Box Culvert    LRPSb
# 15394  Z8948   1.010            Box Culvert  LRP001a
# 15396  Z8948   2.070  Steel Beam & RCC Slab  LRP002a
# 15397  Z8948   2.100  Steel Beam & RCC Slab  LRP002c
#
#                             name  length condition  structureNr  \
# 0                              .    11.3         A       117861
# 1                              .     6.6         A       117862
# 13420  KANCHPUR PC GIRDER BRIDGE   397.0         C       101102
# 15398       KATCHPUR BOX CULVERT     8.0         B       101106
# 3               NOYAPARA CULVERT     6.3         A       112531
# ...                          ...     ...       ...          ...
# 15392                          .     2.0         A       116832
# 15393                          .     2.0         A       116833
# 15394                          .     2.0         A       116834
# 15396                          .    18.5         A       116835
# 15397                          .    18.5         A       116836
#
#                                                 roadName  chainage  ...  \
# 0      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...     1.800  ...
# 1      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...     4.925  ...
# 13420  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...     8.976  ...
# 15398  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    10.543  ...
# 3      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    10.880  ...
# ...                                                  ...       ...  ...
# 15392                           Fakirhat-Khasherhat Road     0.306  ...
# 15393                           Fakirhat-Khasherhat Road     0.640  ...
# 15394                           Fakirhat-Khasherhat Road     1.010  ...
# 15396                           Fakirhat-Khasherhat Road     2.070  ...
# 15397                           Fakirhat-Khasherhat Road     2.100  ...
#
#        spans     zone   circle     division   sub-division        lat  \
# 0        2.0    Dhaka    Dhaka  Narayanganj  Narayanganj-1  23.702889
# 1        1.0    Dhaka    Dhaka  Narayanganj  Narayanganj-1  23.693611
# 13420    8.0    Dhaka    Dhaka  Narayanganj  Narayanganj-1  23.702083
# 15398    2.0    Dhaka    Dhaka  Narayanganj      Vitikandi  23.702056
# 3        2.0    Dhaka    Dhaka  Narayanganj      Vitikandi  23.699833
# ...      ...      ...      ...          ...            ...        ...
# 15392    1.0  Barisal  Barisal        Bhola          Bhola  22.425278
# 15393    1.0  Barisal  Barisal        Bhola          Bhola  22.422778
# 15394    1.0  Barisal  Barisal        Bhola          Bhola  22.419167
# 15396    3.0  Barisal  Barisal        Bhola          Bhola  22.414167
# 15397    3.0  Barisal  Barisal        Bhola          Bhola  22.414167
#
#              lon  EstimatedLoc   road_LRPName null_num
# 0      90.450389          bcs1     N1_LRP001a        0
# 1      90.478833          bcs1     N1_LRP004b        0
# 13420  90.515917          bcs1     N1_LRP008b        0
# 15398  90.528194          bcs1     N1_LRP010a        0
# 3      90.530722          bcs1     N1_LRP010b        0
# ...          ...           ...            ...      ...
# 15392  90.787778          bcs1    Z8948_LRPSa        0
# 15393  90.787222          bcs1    Z8948_LRPSb        0
# 15394  90.787500          bcs1  Z8948_LRP001a        0
# 15396  90.791667          bcs1  Z8948_LRP002a        0
# 15397  90.791944          bcs1  Z8948_LRP002c        0
#
# [17783 rows x 22 columns]

# %%
# Remove columns 'road_LRPName' and 'null_num'
df_final_bridges = df_bridges_no_lrp_after_e.drop(columns=['road_LRPName', 'null_num'])

# reset the index
df_final_bridges = df_final_bridges.reset_index(drop=True)

# %%
import numpy as np

# compare cleaned_bridges with df_final_bridges; print lrps that are different
for road in df_final_bridges['road'].unique():
    cleaned_lrps = cleaned_bridges[cleaned_bridges['road'] == road]['LRPName'].values
    final_lrps = df_final_bridges[df_final_bridges['road'] == road]['LRPName'].values
    
    if not np.array_equal(cleaned_lrps, final_lrps):
        print(df_lrpe_road[df_lrpe_road['road'] == road]["LRP_before_E"])
        print(f'Road: {road}')
        print(f'Cleaned LRPs: {cleaned_lrps}')
        print(f'Final LRPs: {final_lrps}')
        print()
# Out:
# 2    LRP082a
# Name: LRP_before_E, dtype: object
# Road: N102
# Cleaned LRPs: ['LRP002a' 'LRP002b' 'LRP002c' 'LRP004a' 'LRP007a' 'LRP008a' 'LRP009a'
#  'LRP010c' 'LRP011a' 'LRP011b' 'LRP012a' 'LRP015a' 'LRP017a' 'LRP018a'
#  'LRP019a' 'LRP019b' 'LRP021a' 'LRP021b' 'LRP021c' 'LRP022a' 'LRP023b'
#  'LRP024b' 'LRP025b' 'LRP026a' 'LRP027a' 'LRP028a' 'LRP028c' 'LRP029a'
#  'LRP029b' 'LRP029d' 'LRP030a' 'LRP031a' 'LRP031b' 'LRP031c' 'LRP032a'
#  'LRP033a' 'LRP033c' 'LRP034a' 'LRP034b' 'LRP035a' 'LRP035c' 'LRP036a'
#  'LRP036b' 'LRP036d' 'LRP037a' 'LRP037c' 'LRP037d' 'LRP038b' 'LRP038d'
#  'LRP039a' 'LRP040a' 'LRP041a' 'LRP043a' 'LRP044a' 'LRP044c' 'LRP045a'
#  'LRP046a' 'LRP047a' 'LRP048a' 'LRP049a' 'LRP050a' 'LRP050c' 'LRP051b'
#  'LRP052a' 'LRP053a' 'LRP055a' 'LRP055c' 'LRP056b' 'LRP058a' 'LRP059a'
#  'LRP059b' 'LRP060a' 'LRP062b' 'LRP062c' 'LRP063a' 'LRP064b' 'LRP065a'
#  'LRP066a' 'LRP067a' 'LRP067c' 'LRP069a' 'LRP070a' 'LRP073e' 'LRP077a'
#  'LRP078a' 'LRP078b' 'LRP079a' 'LRP080a' 'LRP082a' 'LRPSc']
# Final LRPs: ['LRPSc' 'LRP002a' 'LRP002b' 'LRP002c' 'LRP008a' 'LRP009a' 'LRP010c'
#  'LRP011a' 'LRP015a' 'LRP017a' 'LRP019a' 'LRP019b' 'LRP021b' 'LRP021c'
#  'LRP022a' 'LRP023b' 'LRP024b' 'LRP025b' 'LRP026a' 'LRP028c' 'LRP029a'
#  'LRP029d' 'LRP033c' 'LRP034b' 'LRP036a' 'LRP036b' 'LRP036d' 'LRP037c'
#  'LRP037d' 'LRP038b' 'LRP038d' 'LRP043a' 'LRP044a' 'LRP045a' 'LRP046a'
#  'LRP050a' 'LRP052a' 'LRP055c' 'LRP058a' 'LRP062b' 'LRP062c' 'LRP063a'
#  'LRP064b' 'LRP065a' 'LRP066a' 'LRP078a' 'LRP079a' 'LRP082a']
#
# 4    LRP049c
# Name: LRP_before_E, dtype: object
# Road: N104
# Cleaned LRPs: ['LRP002a' 'LRP004b' 'LRP008a' 'LRP008b' 'LRP009a' 'LRP010a' 'LRP011a'
#  'LRP013a' 'LRP015a' 'LRP017b' 'LRP019a' 'LRP019b' 'LRP021a' 'LRP022a'
#  'LRP023b' 'LRP025a' 'LRP027a' 'LRP028a' 'LRP030a' 'LRP031a' 'LRP032a'
#  'LRP034a' 'LRP035a' 'LRP036a' 'LRP036b' 'LRP037a' 'LRP038a' 'LRP038c'
#  'LRP040a' 'LRP040b' 'LRP044b' 'LRP044d' 'LRP045a' 'LRP045b' 'LRP047a'
#  'LRP047c' 'LRP048a' 'LRP048b' 'LRPSa' 'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP002a' 'LRP004b' 'LRP008a' 'LRP008b' 'LRP009a'
#  'LRP010a' 'LRP011a' 'LRP013a' 'LRP015a' 'LRP017b' 'LRP019a' 'LRP019b'
#  'LRP021a' 'LRP022a' 'LRP023b' 'LRP025a' 'LRP027a' 'LRP028a' 'LRP030a'
#  'LRP031a' 'LRP032a' 'LRP034a' 'LRP035a' 'LRP036a' 'LRP036b' 'LRP037a'
#  'LRP038a' 'LRP038c' 'LRP040a' 'LRP040b' 'LRP044b' 'LRP044d' 'LRP045a'
#  'LRP045b' 'LRP047a' 'LRP047c' 'LRP048a' 'LRP048b']
#
# 5    LRP048
# Name: LRP_before_E, dtype: object
# Road: N105
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP003a' 'LRP005c' 'LRP006a' 'LRP017a' 'LRP017b'
#  'LRP017c' 'LRP019a' 'LRP020c' 'LRP021a' 'LRP021d' 'LRP022a' 'LRP022c'
#  'LRP023c' 'LRP024b' 'LRP024c' 'LRP027a' 'LRP027c' 'LRP028a' 'LRP028b'
#  'LRP029a' 'LRP029b' 'LRP030a' 'LRP030c' 'LRP032a' 'LRP032b' 'LRP032c'
#  'LRP033a' 'LRP035a' 'LRP035d' 'LRP036a' 'LRP036c' 'LRP037a' 'LRP039a'
#  'LRP039b' 'LRP040a' 'LRP040b' 'LRP040c' 'LRP041b' 'LRP041c' 'LRP042a'
#  'LRP042b' 'LRP043a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP002a' 'LRP003a' 'LRP005c' 'LRP006a' 'LRP017a'
#  'LRP017b' 'LRP017c' 'LRP019a' 'LRP020c' 'LRP021a' 'LRP021d' 'LRP022a'
#  'LRP022c' 'LRP023c' 'LRP024b' 'LRP024c' 'LRP027a' 'LRP027c' 'LRP028a'
#  'LRP028b' 'LRP029a' 'LRP029b' 'LRP030a' 'LRP030c' 'LRP032a' 'LRP032b'
#  'LRP032c' 'LRP033a' 'LRP035a' 'LRP035d' 'LRP036a' 'LRP036c' 'LRP037a'
#  'LRP039a' 'LRP039b' 'LRP040a' 'LRP040b' 'LRP040c' 'LRP041b' 'LRP041c'
#  'LRP042a' 'LRP042b' 'LRP043a']
#
# 6    LRP069
# Name: LRP_before_E, dtype: object
# Road: N106
# Cleaned LRPs: ['LRP001b' 'LRP002a' 'LRP002c' 'LRP003a' 'LRP003b' 'LRP004a' 'LRP006a'
#  'LRP006b' 'LRP007a' 'LRP007b' 'LRP008a' 'LRP009a' 'LRP009c' 'LRP010a'
#  'LRP012a' 'LRP012c' 'LRP014b' 'LRP015a' 'LRP016a' 'LRP017a' 'LRP018a'
#  'LRP018c' 'LRP019a' 'LRP020a' 'LRP020c' 'LRP020d' 'LRP021b' 'LRP022a'
#  'LRP022b' 'LRP023b' 'LRP023c' 'LRP024a' 'LRP024c' 'LRP024e' 'LRP025b'
#  'LRP026c' 'LRP027a' 'LRP027b' 'LRP027c' 'LRP030b' 'LRP031c' 'LRP032a'
#  'LRP032c' 'LRP032d' 'LRP033a' 'LRP033b' 'LRP033c' 'LRP033d' 'LRP034c'
#  'LRP034d' 'LRP034e' 'LRP035a' 'LRP035b' 'LRP035c' 'LRP035d' 'LRP035e'
#  'LRP035f' 'LRP036a' 'LRP037a' 'LRP037b' 'LRP037c' 'LRP038a' 'LRP038c'
#  'LRP038e' 'LRP039a' 'LRP039b' 'LRP040a' 'LRP041a' 'LRP041b' 'LRP042a'
#  'LRP042c' 'LRP042d' 'LRP043b' 'LRP043c' 'LRP044a' 'LRP044b' 'LRP045a'
#  'LRP046a' 'LRP046c' 'LRP047a' 'LRP049a' 'LRP050b' 'LRP051b' 'LRP051d'
#  'LRP051e' 'LRP052a' 'LRP052b' 'LRP053a' 'LRP053b' 'LRP053d' 'LRP053e'
#  'LRP053f' 'LRP053g' 'LRP054b' 'LRP054c' 'LRP055b' 'LRP056a' 'LRP056c'
#  'LRP058a' 'LRPSa' 'LRPSb' 'LRPSc']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRPSc' 'LRP001b' 'LRP002a' 'LRP002c' 'LRP003a' 'LRP003b'
#  'LRP004a' 'LRP006a' 'LRP006b' 'LRP007a' 'LRP007b' 'LRP008a' 'LRP009a'
#  'LRP009c' 'LRP010a' 'LRP012a' 'LRP012c' 'LRP014b' 'LRP015a' 'LRP016a'
#  'LRP017a' 'LRP018a' 'LRP018c' 'LRP019a' 'LRP020a' 'LRP020c' 'LRP020d'
#  'LRP021b' 'LRP022a' 'LRP022b' 'LRP023b' 'LRP023c' 'LRP024a' 'LRP024c'
#  'LRP024e' 'LRP025b' 'LRP026c' 'LRP027a' 'LRP027b' 'LRP027c' 'LRP030b'
#  'LRP031c' 'LRP032a' 'LRP032c' 'LRP032d' 'LRP033a' 'LRP033b' 'LRP033c'
#  'LRP033d' 'LRP034c' 'LRP034d' 'LRP034e' 'LRP035a' 'LRP035b' 'LRP035c'
#  'LRP035d' 'LRP035e' 'LRP035f' 'LRP036a' 'LRP037a' 'LRP037b' 'LRP037c'
#  'LRP038a' 'LRP038c' 'LRP038e' 'LRP039a' 'LRP039b' 'LRP040a' 'LRP041a'
#  'LRP041b' 'LRP042a' 'LRP042c' 'LRP042d' 'LRP043b' 'LRP043c' 'LRP044a'
#  'LRP044b' 'LRP045a' 'LRP046a' 'LRP046c' 'LRP047a' 'LRP049a' 'LRP050b'
#  'LRP051b' 'LRP051d' 'LRP051e' 'LRP052a' 'LRP052b' 'LRP053a' 'LRP053b'
#  'LRP053d' 'LRP053e' 'LRP053f' 'LRP053g' 'LRP054b' 'LRP054c' 'LRP055b'
#  'LRP056a' 'LRP056c' 'LRP058a']
#
# 7    LRP010a
# Name: LRP_before_E, dtype: object
# Road: N107
# Cleaned LRPs: ['LRP001a' 'LRP003a' 'LRP004a' 'LRP004b' 'LRP006a' 'LRP007a' 'LRP008a'
#  'LRP008b' 'LRP010a' 'LRPSa' 'LRPSc']
# Final LRPs: ['LRPSa' 'LRPSc' 'LRP001a' 'LRP004a' 'LRP004b' 'LRP010a']
#
# 8    LRP022
# Name: LRP_before_E, dtype: object
# Road: N108
# Cleaned LRPs: ['LRP001a' 'LRP001c' 'LRP002a' 'LRP002c' 'LRP004a' 'LRP005a' 'LRP005b'
#  'LRP005c' 'LRP006a' 'LRP006c' 'LRP007c' 'LRP008a' 'LRP010a' 'LRP010b'
#  'LRP011a' 'LRP012a' 'LRP012b' 'LRP012d' 'LRP012f' 'LRP012g' 'LRP012i'
#  'LRP012j' 'LRP013a' 'LRP013c' 'LRP013d' 'LRP013e' 'LRP013f' 'LRP013g'
#  'LRP014a' 'LRP014b' 'LRP014c' 'LRP014d' 'LRP014e' 'LRP014f' 'LRP015a'
#  'LRP018a' 'LRP020a' 'LRP020c' 'LRP020e' 'LRP021a' 'LRP021b' 'LRP021c'
#  'LRP021e' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001c' 'LRP002a' 'LRP002c' 'LRP004a' 'LRP005a'
#  'LRP005b' 'LRP005c' 'LRP006a' 'LRP006c' 'LRP007c' 'LRP008a' 'LRP010a'
#  'LRP010b' 'LRP011a' 'LRP012a' 'LRP012b' 'LRP012d' 'LRP012f' 'LRP012g'
#  'LRP012i' 'LRP012j' 'LRP013a' 'LRP013c' 'LRP013d' 'LRP013e' 'LRP013f'
#  'LRP013g' 'LRP014a' 'LRP014b' 'LRP014c' 'LRP014d' 'LRP014e' 'LRP014f'
#  'LRP015a' 'LRP018a' 'LRP020a' 'LRP020c' 'LRP020e' 'LRP021a' 'LRP021b'
#  'LRP021c' 'LRP021e']
#
# 10    LRP008
# Name: LRP_before_E, dtype: object
# Road: N110
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002a' 'LRP003a' 'LRP003b' 'LRP004a' 'LRP004b'
#  'LRP004c' 'LRP005a' 'LRP005b' 'LRP005c' 'LRP005d' 'LRP005e' 'LRP006a'
#  'LRP006b' 'LRP007a' 'LRPSa' 'LRPSb' 'LRPsd']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP001a' 'LRP001b' 'LRP002a' 'LRP003a' 'LRP003b'
#  'LRP004a' 'LRP004b' 'LRP004c' 'LRP005a' 'LRP005b' 'LRP005c' 'LRP005d'
#  'LRP005e' 'LRP006a' 'LRP006b' 'LRP007a' 'LRPsd']
#
# 24    LRP036a
# Name: LRP_before_E, dtype: object
# Road: N204
# Cleaned LRPs: ['LRP001a' 'LRP001c' 'LRP001d' 'LRP002a' 'LRP003a' 'LRP003b' 'LRP010a'
#  'LRP012b' 'LRP012c' 'LRP014a' 'LRP014c' 'LRP015a' 'LRP017a' 'LRP019b'
#  'LRP020a' 'LRP020b' 'LRP020c' 'LRP021a' 'LRP025a' 'LRP025c' 'LRP029a'
#  'LRP032a' 'LRP033a' 'LRP034a' 'LRP034b' 'LRP035a' 'LRP035c' 'LRP038a'
#  'LRP038b' 'LRP040a' 'LRP041a' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP001a' 'LRP001c' 'LRP001d' 'LRP002a' 'LRP003a' 'LRP003b'
#  'LRP010a' 'LRP012b' 'LRP012c' 'LRP014a' 'LRP014c' 'LRP015a' 'LRP017a'
#  'LRP019b' 'LRP020a' 'LRP020b' 'LRP020c' 'LRP021a' 'LRP025a' 'LRP025c'
#  'LRP029a' 'LRP032a' 'LRP033a' 'LRP034a' 'LRP034b' 'LRP035a' 'LRP035c'
#  'LRP038a' 'LRP038b' 'LRP040a' 'LRP041a']
#
# 25    LRP002
# Name: LRP_before_E, dtype: object
# Road: N205
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP002b' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP002a' 'LRP002b']
#
# 27    LRP068
# Name: LRP_before_E, dtype: object
# Road: N207
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP002d' 'LRP003a' 'LRP004b' 'LRP006b' 'LRP008a'
#  'LRP008c' 'LRP014a' 'LRP017b' 'LRP018a' 'LRP018c' 'LRP019a' 'LRP020a'
#  'LRP020c' 'LRP022b' 'LRP023b' 'LRP025a' 'LRP025b' 'LRP025d' 'LRP025e'
#  'LRP026a' 'LRP026c' 'LRP027a' 'LRP027c' 'LRP028a' 'LRP028b' 'LRP029a'
#  'LRP029b' 'LRP030a' 'LRP030b' 'LRP030d' 'LRP032a' 'LRP032c' 'LRP033a'
#  'LRP033b' 'LRP034a' 'LRP035b' 'LRP036b' 'LRP037b' 'LRP037c' 'LRP038a'
#  'LRP038b' 'LRP039a' 'LRP039b' 'LRP040a' 'LRP040b' 'LRP041a' 'LRP041b'
#  'LRP042a' 'LRP043a' 'LRP051a' 'LRP051b' 'LRP052a' 'LRP053a' 'LRP056a'
#  'LRP057a' 'LRP060a' 'LRP061c' 'LRP061d' 'LRP062a' 'LRP063a' 'LRP064a'
#  'LRP065a' 'LRP066b' 'LRP068a' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP001a' 'LRP002a' 'LRP002d' 'LRP003a' 'LRP004b' 'LRP006b'
#  'LRP008a' 'LRP008c' 'LRP014a' 'LRP017b' 'LRP018a' 'LRP018c' 'LRP019a'
#  'LRP020a' 'LRP020c' 'LRP022b' 'LRP023b' 'LRP025a' 'LRP025b' 'LRP025d'
#  'LRP025e' 'LRP026a' 'LRP026c' 'LRP027a' 'LRP027c' 'LRP028a' 'LRP028b'
#  'LRP029a' 'LRP029b' 'LRP030a' 'LRP030b' 'LRP030d' 'LRP032a' 'LRP032c'
#  'LRP033a' 'LRP033b' 'LRP034a' 'LRP035b' 'LRP036b' 'LRP037b' 'LRP037c'
#  'LRP038a' 'LRP038b' 'LRP039a' 'LRP039b' 'LRP040a' 'LRP040b' 'LRP041a'
#  'LRP041b' 'LRP042a' 'LRP043a' 'LRP051a' 'LRP051b' 'LRP052a' 'LRP053a'
#  'LRP056a' 'LRP057a' 'LRP060a' 'LRP061c' 'LRP061d' 'LRP062a' 'LRP063a'
#  'LRP064a' 'LRP065a' 'LRP066b' 'LRP068a']
#
# 28    LRP058
# Name: LRP_before_E, dtype: object
# Road: N208
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP003b' 'LRP004a' 'LRP004c' 'LRP005a' 'LRP005c'
#  'LRP006a' 'LRP007a' 'LRP008a' 'LRP009a' 'LRP010a' 'LRP010b' 'LRP011a'
#  'LRP011b' 'LRP012a' 'LRP013b' 'LRP014a' 'LRP015a' 'LRP016a' 'LRP016b'
#  'LRP017a' 'LRP017c' 'LRP019a' 'LRP020a' 'LRP020c' 'LRP020d' 'LRP021b'
#  'LRP022a' 'LRP022b' 'LRP023a' 'LRP023b' 'LRP023c' 'LRP024b' 'LRP024d'
#  'LRP025a' 'LRP025b' 'LRP025d' 'LRP026a' 'LRP027a' 'LRP027b' 'LRP027d'
#  'LRP027e' 'LRP027f' 'LRP028a' 'LRP028c' 'LRP028d' 'LRP028e' 'LRP029a'
#  'LRP029b' 'LRP029c' 'LRP030a' 'LRP030b' 'LRP031a' 'LRP031b' 'LRP031c'
#  'LRP031d' 'LRP032a' 'LRP032b' 'LRP032c' 'LRP033a' 'LRP033b' 'LRP034a'
#  'LRP034b' 'LRP034c' 'LRP034d' 'LRP035a' 'LRP035b' 'LRP035c' 'LRP035d'
#  'LRP035e' 'LRP036a' 'LRP036c' 'LRP036e' 'LRP038a' 'LRP039a' 'LRP041a'
#  'LRP041c' 'LRP042a' 'LRP044a' 'LRP045a' 'LRP046a' 'LRP046b' 'LRP048a'
#  'LRP051a' 'LRP052a' 'LRP055a' 'LRP057b' 'LRP057d' 'LRP057e' 'LRP058b'
#  'LRP058d' 'LRPSa' 'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP001a' 'LRP002a' 'LRP003b' 'LRP004a' 'LRP004c'
#  'LRP005a' 'LRP005c' 'LRP006a' 'LRP007a' 'LRP008a' 'LRP009a' 'LRP010a'
#  'LRP010b' 'LRP011a' 'LRP011b' 'LRP012a' 'LRP013b' 'LRP014a' 'LRP015a'
#  'LRP016a' 'LRP016b' 'LRP017a' 'LRP017c' 'LRP019a' 'LRP020a' 'LRP020c'
#  'LRP020d' 'LRP021b' 'LRP022a' 'LRP022b' 'LRP023a' 'LRP023b' 'LRP023c'
#  'LRP024b' 'LRP024d' 'LRP025a' 'LRP025b' 'LRP025d' 'LRP026a' 'LRP027a'
#  'LRP027b' 'LRP027d' 'LRP027e' 'LRP027f' 'LRP028a' 'LRP028c' 'LRP028d'
#  'LRP028e' 'LRP029a' 'LRP029b' 'LRP029c' 'LRP030a' 'LRP030b' 'LRP031a'
#  'LRP031b' 'LRP031c' 'LRP031d' 'LRP032a' 'LRP032b' 'LRP032c' 'LRP033a'
#  'LRP033b' 'LRP034a' 'LRP034b' 'LRP034c' 'LRP034d' 'LRP035a' 'LRP035b'
#  'LRP035c' 'LRP035d' 'LRP035e' 'LRP036a' 'LRP036c' 'LRP036e' 'LRP038a'
#  'LRP039a' 'LRP041a' 'LRP041c' 'LRP042a' 'LRP044a' 'LRP045a' 'LRP046a'
#  'LRP046b' 'LRP048a' 'LRP051a' 'LRP052a' 'LRP055a' 'LRP057b' 'LRP057d'
#  'LRP057e' 'LRP058b' 'LRP058d']
#
# 29    LRP001
# Name: LRP_before_E, dtype: object
# Road: N209
# Cleaned LRPs: ['LRP001a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a']
#
# 34    LRP113
# Name: LRP_before_E, dtype: object
# Road: N3
# Cleaned LRPs: ['LRP009b' 'LRP013a' 'LRP014a' 'LRP016a' 'LRP016b' 'LRP020b' 'LRP022b'
#  'LRP023a' 'LRP024a' 'LRP026a' 'LRP026c' 'LRP033a' 'LRP033b' 'LRP033c'
#  'LRP034b' 'LRP035a' 'LRP035b' 'LRP036a' 'LRP036b' 'LRP038a' 'LRP038b'
#  'LRP039a' 'LRP040a' 'LRP041a' 'LRP046a' 'LRP047a' 'LRP048a' 'LRP048b'
#  'LRP049c' 'LRP050a' 'LRP050b' 'LRP050c' 'LRP050d' 'LRP051a' 'LRP051b'
#  'LRP052a' 'LRP053a' 'LRP054a' 'LRP056a' 'LRP060a' 'LRP062a' 'LRP065a'
#  'LRP066a' 'LRP066b' 'LRP066c' 'LRP066d' 'LRP066e' 'LRP070a' 'LRP072d'
#  'LRP073a' 'LRP074a' 'LRP074b' 'LRP075a' 'LRP076a' 'LRP076b' 'LRP077b'
#  'LRP077c' 'LRP080b' 'LRP080c' 'LRP082a' 'LRP082b' 'LRP083a' 'LRP083b'
#  'LRP083c' 'LRP085a' 'LRP086a' 'LRP086b' 'LRP087a' 'LRP088a' 'LRP089a'
#  'LRP090a' 'LRP091a' 'LRP091b' 'LRP092a' 'LRP092c' 'LRP094a' 'LRP094b'
#  'LRP095a' 'LRP095b' 'LRP095c' 'LRP096a' 'LRP096b' 'LRP096c' 'LRP098a'
#  'LRP099a' 'LRP099b' 'LRP100a' 'LRP100b' 'LRP102a' 'LRP103a' 'LRP105a'
#  'LRP106a' 'LRP106b' 'LRP107a' 'LRP108b' 'LRP109a' 'LRP109b' 'LRP109c'
#  'LRP110a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP009b' 'LRP013a' 'LRP014a' 'LRP016a' 'LRP016b' 'LRP020b'
#  'LRP022b' 'LRP023a' 'LRP024a' 'LRP026a' 'LRP026c' 'LRP033a' 'LRP033b'
#  'LRP033c' 'LRP034b' 'LRP035a' 'LRP035b' 'LRP036a' 'LRP036b' 'LRP038a'
#  'LRP038b' 'LRP039a' 'LRP040a' 'LRP041a' 'LRP046a' 'LRP047a' 'LRP048a'
#  'LRP048b' 'LRP049c' 'LRP050a' 'LRP050b' 'LRP050c' 'LRP050d' 'LRP051a'
#  'LRP051b' 'LRP052a' 'LRP053a' 'LRP054a' 'LRP056a' 'LRP060a' 'LRP062a'
#  'LRP065a' 'LRP066a' 'LRP066b' 'LRP066c' 'LRP066d' 'LRP066e' 'LRP070a'
#  'LRP072d' 'LRP073a' 'LRP074a' 'LRP074b' 'LRP075a' 'LRP076a' 'LRP076b'
#  'LRP077b' 'LRP077c' 'LRP080b' 'LRP080c' 'LRP082a' 'LRP082b' 'LRP083a'
#  'LRP083b' 'LRP083c' 'LRP085a' 'LRP086a' 'LRP086b' 'LRP087a' 'LRP088a'
#  'LRP089a' 'LRP090a' 'LRP091a' 'LRP091b' 'LRP092a' 'LRP092c' 'LRP094a'
#  'LRP094b' 'LRP095a' 'LRP095b' 'LRP095c' 'LRP096a' 'LRP096b' 'LRP096c'
#  'LRP098a' 'LRP099a' 'LRP099b' 'LRP100a' 'LRP100b' 'LRP102a' 'LRP103a'
#  'LRP105a' 'LRP106a' 'LRP106b' 'LRP107a' 'LRP108b' 'LRP109a' 'LRP109b'
#  'LRP109c' 'LRP110a']
#
# 37    LRP014
# Name: LRP_before_E, dtype: object
# Road: N309
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002a' 'LRP002b' 'LRP002c' 'LRP003b' 'LRP003c'
#  'LRP004a' 'LRP004b' 'LRP005a' 'LRPSc' 'LRPSd']
# Final LRPs: ['LRPSc' 'LRPSd' 'LRP001a' 'LRP001b' 'LRP002a' 'LRP002b' 'LRP002c'
#  'LRP003b' 'LRP003c' 'LRP004a' 'LRP004b' 'LRP005a']
#
# 41    LRP003c
# Name: LRP_before_E, dtype: object
# Road: N403
# Cleaned LRPs: ['LRP001a' 'LRP003a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP003a']
#
# 43    LRP040b
# Name: LRP_before_E, dtype: object
# Road: N405
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002a' 'LRP002c' 'LRP003a' 'LRP003b' 'LRP004a'
#  'LRP004b' 'LRP005a' 'LRP005b' 'LRP006a' 'LRP006c' 'LRP007a' 'LRP008a'
#  'LRP008c' 'LRP008d' 'LRP010a' 'LRP014a' 'LRP015a' 'LRP015b' 'LRP016a'
#  'LRP016b' 'LRP017a' 'LRP018a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001b' 'LRP002a' 'LRP002c' 'LRP003a' 'LRP003b'
#  'LRP004a' 'LRP004b' 'LRP005a' 'LRP005b' 'LRP006a' 'LRP006c' 'LRP007a'
#  'LRP008a' 'LRP008c' 'LRP008d' 'LRP010a' 'LRP014a' 'LRP015a' 'LRP015b'
#  'LRP016a' 'LRP016b' 'LRP017a' 'LRP018a']
#
# 47    LRP524
# Name: LRP_before_E, dtype: object
# Road: N5
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP003a' 'LRP004a' 'LRP005a' 'LRP005b' 'LRP008a'
#  'LRP008b' 'LRP010a' 'LRP010b' 'LRP010c' 'LRP010d' 'LRP019a' 'LRP021a'
#  'LRP024a' 'LRP024c' 'LRP024d' 'LRP025a' 'LRP026a' 'LRP027b' 'LRP029a'
#  'LRP029c' 'LRP030a' 'LRP031a' 'LRP032a' 'LRP034a' 'LRP034c' 'LRP034e'
#  'LRP035a' 'LRP035c' 'LRP036a' 'LRP036c' 'LRP037a' 'LRP038a' 'LRP039a'
#  'LRP040a' 'LRP042a' 'LRP043a' 'LRP043c' 'LRP044a' 'LRP045a' 'LRP046a'
#  'LRP046d' 'LRP049a' 'LRP049c' 'LRP050a' 'LRP051a' 'LRP052b' 'LRP053a'
#  'LRP055a' 'LRP056a' 'LRP056c' 'LRP057b' 'LRP058b' 'LRP059a' 'LRP059c'
#  'LRP060a' 'LRP060c' 'LRP061a' 'LRP061c' 'LRP062a' 'LRP063a' 'LRP063c'
#  'LRP065a' 'LRP066b' 'LRP067a' 'LRP068a' 'LRP069a' 'LRP072a' 'LRP073b'
#  'LRP074a' 'LRP075a' 'LRP075b' 'LRP076a' 'LRP077a' 'LRP078a' 'LRP099a'
#  'LRP100b' 'LRP102a' 'LRP102c' 'LRP103a' 'LRP105a' 'LRP107a' 'LRP111a'
#  'LRP112b' 'LRP114a' 'LRP114c' 'LRP115a' 'LRP115c' 'LRP116a' 'LRP118a'
#  'LRP119a' 'LRP120a' 'LRP122a' 'LRP123b' 'LRP125a' 'LRP126a' 'LRP127a'
#  'LRP128a' 'LRP129a' 'LRP129b' 'LRP130a' 'LRP131a' 'LRP133a' 'LRP133c'
#  'LRP133e' 'LRP134a' 'LRP135a' 'LRP135c' 'LRP136a' 'LRP136d' 'LRP138a'
#  'LRP139a' 'LRP139b' 'LRP140a' 'LRP140c' 'LRP142a' 'LRP143a' 'LRP144a'
#  'LRP147a' 'LRP147c' 'LRP148b' 'LRP151b' 'LRP152a' 'LRP152c' 'LRP153a'
#  'LRP156a' 'LRP158a' 'LRP159a' 'LRP159c' 'LRP160a' 'LRP160c' 'LRP160e'
#  'LRP160g' 'LRP161a' 'LRP161c' 'LRP162a' 'LRP163a' 'LRP163c' 'LRP164a'
#  'LRP165a' 'LRP165c' 'LRP166a' 'LRP167a' 'LRP168a' 'LRP169a' 'LRP170a'
#  'LRP171a' 'LRP172a' 'LRP172c' 'LRP173a' 'LRP174a' 'LRP174b' 'LRP175a'
#  'LRP176a' 'LRP177a' 'LRP179a' 'LRP180a' 'LRP180b' 'LRP181a' 'LRP181b'
#  'LRP181c' 'LRP182a' 'LRP182c' 'LRP183a' 'LRP184a' 'LRP184b' 'LRP185a'
#  'LRP185b' 'LRP186a' 'LRP186c' 'LRP187a' 'LRP188a' 'LRP189a' 'LRP194a'
#  'LRP201a' 'LRP210a' 'LRP211a' 'LRP215a' 'LRP217c' 'LRP219c' 'LRP222b'
#  'LRP223a' 'LRP224b' 'LRP225a' 'LRP227a' 'LRP227c' 'LRP233a' 'LRP234a'
#  'LRP235a' 'LRP236a' 'LRP237a' 'LRP237b' 'LRP237c' 'LRP238a' 'LRP239a'
#  'LRP239b' 'LRP240a' 'LRP240b' 'LRP241a' 'LRP244a' 'LRP248a' 'LRP249a'
#  'LRP250a' 'LRP251a' 'LRP252a' 'LRP254a' 'LRP258b' 'LRP258c' 'LRP259a'
#  'LRP259b' 'LRP260a' 'LRP260b' 'LRP261a' 'LRP262a' 'LRP262c' 'LRP262d'
#  'LRP263a' 'LRP264a' 'LRP265a' 'LRP265c' 'LRP266a' 'LRP266b' 'LRP267a'
#  'LRP269a' 'LRP269b' 'LRP270a' 'LRP271a' 'LRP272a' 'LRP275a' 'LRP277a'
#  'LRP277b' 'LRP278a' 'LRP279a' 'LRP279c' 'LRP280a' 'LRP280b' 'LRP281a'
#  'LRP282a' 'LRP286a' 'LRP286b' 'LRP287a' 'LRP288a' 'LRP288b' 'LRP289a'
#  'LRP291a' 'LRP291b' 'LRP297a' 'LRP298a' 'LRP299a' 'LRP302a' 'LRP304a'
#  'LRP306a' 'LRP308b' 'LRP310a' 'LRP311a' 'LRP312a' 'LRP313a' 'LRP314a'
#  'LRP315a' 'LRP316a' 'LRP317a' 'LRP318a' 'LRP319a' 'LRP322a' 'LRP323d'
#  'LRP325a' 'LRP325b' 'LRP326a' 'LRP327a' 'LRP328b' 'LRP328c' 'LRP329a'
#  'LRP330a' 'LRP332a' 'LRP334a' 'LRP336a' 'LRP336b' 'LRP338a' 'LRP339a'
#  'LRP341a' 'LRP342a' 'LRP343a' 'LRP344a' 'LRP344c' 'LRP345a' 'LRP346a'
#  'LRP347a' 'LRP350a' 'LRP350b' 'LRP354a' 'LRP356a' 'LRP359a' 'LRP359b'
#  'LRP360a' 'LRP361a' 'LRP361b' 'LRP362a' 'LRP363a' 'LRP364a' 'LRP367a'
#  'LRP368a' 'LRP368b' 'LRP368d' 'LRP369c' 'LRP370a' 'LRP372a' 'LRP373a'
#  'LRP374a' 'LRP376a' 'LRP376b' 'LRP376d' 'LRP377a' 'LRP378a' 'LRP379a'
#  'LRP379b' 'LRP380a' 'LRP381a' 'LRP381b' 'LRP381c' 'LRP382a' 'LRP382c'
#  'LRP383a' 'LRP384a' 'LRP384b' 'LRP385a' 'LRP385c' 'LRP385d' 'LRP386a'
#  'LRP386b' 'LRP386c' 'LRP387a' 'LRP388a' 'LRP388b' 'LRP390a' 'LRP391a'
#  'LRP392a' 'LRP394a' 'LRP395a' 'LRP398a' 'LRP399a' 'LRP400a' 'LRP402a'
#  'LRP403a' 'LRP405a' 'LRP409a' 'LRP414a' 'LRP416a' 'LRP417a' 'LRP417b'
#  'LRP418a' 'LRP419a' 'LRP421a' 'LRP422a' 'LRP424a' 'LRP425a' 'LRP427a'
#  'LRP429a' 'LRP429b' 'LRP430a' 'LRP433a' 'LRP434a' 'LRP435a' 'LRP437a'
#  'LRP438a' 'LRP439a' 'LRP440a' 'LRP441a' 'LRP443a' 'LRP444a' 'LRP444b'
#  'LRP446a' 'LRP446b' 'LRP447a' 'LRP448a' 'LRP448b' 'LRP449a' 'LRP449b'
#  'LRP450a' 'LRP451a' 'LRP453a' 'LRP453c' 'LRP454a' 'LRP454b' 'LRP454d'
#  'LRP455a' 'LRP456a' 'LRP457a' 'LRP458a' 'LRP459a' 'LRP459b' 'LRP460a'
#  'LRP461a' 'LRP462a' 'LRP462b' 'LRP466a' 'LRP467a' 'LRP468a' 'LRP468b'
#  'LRP469a' 'LRP471a' 'LRP472a' 'LRP472c' 'LRP473a' 'LRP475a' 'LRP478a'
#  'LRP479a' 'LRP480a' 'LRP482a' 'LRP483a' 'LRP484a' 'LRP485a' 'LRP486a'
#  'LRP488a' 'LRP491a' 'LRP492a' 'LRP493a' 'LRP493b' 'LRP493c' 'LRP494a'
#  'LRP494b' 'LRP495a' 'LRP495b' 'LRP496a' 'LRP497a' 'LRP498a' 'LRP499a'
#  'LRP500a' 'LRP501a' 'LRP502a' 'LRP504a' 'LRP505a' 'LRP505b' 'LRP506a'
#  'LRP507a' 'LRP508a' 'LRP510a' 'LRP511a' 'LRP512a' 'LRP516a' 'LRP517a'
#  'LRP517b' 'LRP521a' 'LRP521b' 'LRP525a' 'LRP527a' 'LRPS' 'LRPSa']
# Final LRPs: ['LRPS' 'LRPSa' 'LRP001a' 'LRP001b' 'LRP003a' 'LRP004a' 'LRP005a'
#  'LRP005b' 'LRP008a' 'LRP008b' 'LRP010a' 'LRP010b' 'LRP010c' 'LRP010d'
#  'LRP019a' 'LRP021a' 'LRP024a' 'LRP024c' 'LRP024d' 'LRP025a' 'LRP026a'
#  'LRP027b' 'LRP029a' 'LRP029c' 'LRP030a' 'LRP031a' 'LRP032a' 'LRP034a'
#  'LRP034c' 'LRP034e' 'LRP035a' 'LRP035c' 'LRP036a' 'LRP036c' 'LRP037a'
#  'LRP038a' 'LRP039a' 'LRP040a' 'LRP042a' 'LRP043a' 'LRP043c' 'LRP044a'
#  'LRP045a' 'LRP046a' 'LRP046d' 'LRP049a' 'LRP049c' 'LRP050a' 'LRP051a'
#  'LRP052b' 'LRP053a' 'LRP055a' 'LRP056a' 'LRP056c' 'LRP057b' 'LRP058b'
#  'LRP059a' 'LRP059c' 'LRP060a' 'LRP060c' 'LRP061a' 'LRP061c' 'LRP062a'
#  'LRP063a' 'LRP063c' 'LRP065a' 'LRP066b' 'LRP067a' 'LRP068a' 'LRP069a'
#  'LRP072a' 'LRP073b' 'LRP074a' 'LRP075a' 'LRP075b' 'LRP076a' 'LRP077a'
#  'LRP078a' 'LRP099a' 'LRP100b' 'LRP102a' 'LRP102c' 'LRP103a' 'LRP105a'
#  'LRP107a' 'LRP111a' 'LRP112b' 'LRP114a' 'LRP114c' 'LRP115a' 'LRP115c'
#  'LRP116a' 'LRP118a' 'LRP119a' 'LRP120a' 'LRP122a' 'LRP123b' 'LRP125a'
#  'LRP126a' 'LRP127a' 'LRP128a' 'LRP129a' 'LRP129b' 'LRP130a' 'LRP131a'
#  'LRP133a' 'LRP133c' 'LRP133e' 'LRP134a' 'LRP135a' 'LRP135c' 'LRP136a'
#  'LRP136d' 'LRP138a' 'LRP139a' 'LRP139b' 'LRP140a' 'LRP140c' 'LRP142a'
#  'LRP143a' 'LRP144a' 'LRP147a' 'LRP147c' 'LRP148b' 'LRP151b' 'LRP152a'
#  'LRP152c' 'LRP153a' 'LRP156a' 'LRP158a' 'LRP159a' 'LRP159c' 'LRP160a'
#  'LRP160c' 'LRP160e' 'LRP160g' 'LRP161a' 'LRP161c' 'LRP162a' 'LRP163a'
#  'LRP163c' 'LRP164a' 'LRP165a' 'LRP165c' 'LRP166a' 'LRP167a' 'LRP168a'
#  'LRP169a' 'LRP170a' 'LRP171a' 'LRP172a' 'LRP172c' 'LRP173a' 'LRP174a'
#  'LRP174b' 'LRP175a' 'LRP176a' 'LRP177a' 'LRP179a' 'LRP180a' 'LRP180b'
#  'LRP181a' 'LRP181b' 'LRP181c' 'LRP182a' 'LRP182c' 'LRP183a' 'LRP184a'
#  'LRP184b' 'LRP185a' 'LRP185b' 'LRP186a' 'LRP186c' 'LRP187a' 'LRP188a'
#  'LRP189a' 'LRP194a' 'LRP201a' 'LRP210a' 'LRP211a' 'LRP215a' 'LRP217c'
#  'LRP219c' 'LRP222b' 'LRP223a' 'LRP224b' 'LRP225a' 'LRP227a' 'LRP227c'
#  'LRP233a' 'LRP234a' 'LRP235a' 'LRP236a' 'LRP237a' 'LRP237b' 'LRP237c'
#  'LRP238a' 'LRP239a' 'LRP239b' 'LRP240a' 'LRP240b' 'LRP241a' 'LRP244a'
#  'LRP248a' 'LRP249a' 'LRP250a' 'LRP251a' 'LRP252a' 'LRP254a' 'LRP258b'
#  'LRP258c' 'LRP259a' 'LRP259b' 'LRP260a' 'LRP260b' 'LRP261a' 'LRP262a'
#  'LRP262c' 'LRP262d' 'LRP263a' 'LRP264a' 'LRP265a' 'LRP265c' 'LRP266a'
#  'LRP266b' 'LRP267a' 'LRP269a' 'LRP269b' 'LRP270a' 'LRP271a' 'LRP272a'
#  'LRP275a' 'LRP277a' 'LRP277b' 'LRP278a' 'LRP279a' 'LRP279c' 'LRP280a'
#  'LRP280b' 'LRP281a' 'LRP282a' 'LRP286a' 'LRP286b' 'LRP287a' 'LRP288a'
#  'LRP288b' 'LRP289a' 'LRP291a' 'LRP291b' 'LRP297a' 'LRP298a' 'LRP299a'
#  'LRP302a' 'LRP304a' 'LRP306a' 'LRP308b' 'LRP310a' 'LRP311a' 'LRP312a'
#  'LRP313a' 'LRP314a' 'LRP315a' 'LRP316a' 'LRP317a' 'LRP318a' 'LRP319a'
#  'LRP322a' 'LRP323d' 'LRP325a' 'LRP325b' 'LRP326a' 'LRP327a' 'LRP328b'
#  'LRP328c' 'LRP329a' 'LRP330a' 'LRP332a' 'LRP334a' 'LRP336a' 'LRP336b'
#  'LRP338a' 'LRP339a' 'LRP341a' 'LRP342a' 'LRP343a' 'LRP344a' 'LRP344c'
#  'LRP345a' 'LRP346a' 'LRP347a' 'LRP350a' 'LRP350b' 'LRP354a' 'LRP356a'
#  'LRP359a' 'LRP359b' 'LRP360a' 'LRP361a' 'LRP361b' 'LRP362a' 'LRP363a'
#  'LRP364a' 'LRP367a' 'LRP368a' 'LRP368b' 'LRP368d' 'LRP369c' 'LRP370a'
#  'LRP372a' 'LRP373a' 'LRP374a' 'LRP376a' 'LRP376b' 'LRP376d' 'LRP377a'
#  'LRP378a' 'LRP379a' 'LRP379b' 'LRP380a' 'LRP381a' 'LRP381b' 'LRP381c'
#  'LRP382a' 'LRP382c' 'LRP383a' 'LRP384a' 'LRP384b' 'LRP385a' 'LRP385c'
#  'LRP385d' 'LRP386a' 'LRP386b' 'LRP386c' 'LRP387a' 'LRP388a' 'LRP388b'
#  'LRP390a' 'LRP391a' 'LRP392a' 'LRP394a' 'LRP395a' 'LRP398a' 'LRP399a'
#  'LRP400a' 'LRP402a' 'LRP403a' 'LRP405a' 'LRP409a' 'LRP414a' 'LRP416a'
#  'LRP417a' 'LRP417b' 'LRP418a' 'LRP419a' 'LRP421a' 'LRP422a' 'LRP424a'
#  'LRP425a' 'LRP427a' 'LRP429a' 'LRP429b' 'LRP430a' 'LRP433a' 'LRP434a'
#  'LRP435a' 'LRP437a' 'LRP438a' 'LRP439a' 'LRP440a' 'LRP441a' 'LRP443a'
#  'LRP444a' 'LRP444b' 'LRP446a' 'LRP446b' 'LRP447a' 'LRP448a' 'LRP448b'
#  'LRP449a' 'LRP449b' 'LRP450a' 'LRP451a' 'LRP453a' 'LRP453c' 'LRP454a'
#  'LRP454b' 'LRP454d' 'LRP455a' 'LRP456a' 'LRP457a' 'LRP458a' 'LRP459a'
#  'LRP459b' 'LRP460a' 'LRP461a' 'LRP462a' 'LRP462b' 'LRP466a' 'LRP467a'
#  'LRP468a' 'LRP468b' 'LRP469a' 'LRP471a' 'LRP472a' 'LRP472c' 'LRP473a'
#  'LRP475a' 'LRP478a' 'LRP479a' 'LRP480a' 'LRP482a' 'LRP483a' 'LRP484a'
#  'LRP485a' 'LRP486a' 'LRP488a' 'LRP491a' 'LRP492a' 'LRP493a' 'LRP493b'
#  'LRP493c' 'LRP494a' 'LRP494b' 'LRP495a' 'LRP495b' 'LRP496a' 'LRP497a'
#  'LRP498a' 'LRP499a' 'LRP500a' 'LRP501a' 'LRP502a' 'LRP504a' 'LRP505a'
#  'LRP505b' 'LRP506a' 'LRP507a' 'LRP508a' 'LRP510a' 'LRP511a' 'LRP512a'
#  'LRP516a' 'LRP517a' 'LRP517b' 'LRP521a' 'LRP521b' 'LRP525a' 'LRP527a']
#
# 49    LRP064
# Name: LRP_before_E, dtype: object
# Road: N502
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP003a' 'LRP005a' 'LRP007a' 'LRP009a' 'LRP011a'
#  'LRP013a' 'LRP014a' 'LRP015a' 'LRP029a' 'LRP029c' 'LRP032a' 'LRP032b'
#  'LRP033a' 'LRP034a' 'LRP035a' 'LRP036a' 'LRP037a' 'LRP038a' 'LRP039a'
#  'LRP040a' 'LRP041a' 'LRP042a' 'LRP043a' 'LRP044a' 'LRP045b' 'LRP046a'
#  'LRP047a' 'LRP048b' 'LRP049a' 'LRP050a' 'LRP052a' 'LRP053a' 'LRP054a'
#  'LRP055a' 'LRP056b' 'LRP057b' 'LRP058a' 'LRP058c' 'LRP059a' 'LRP060a'
#  'LRP060c' 'LRP061a' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP001a' 'LRP002a' 'LRP003a' 'LRP005a' 'LRP007a' 'LRP009a'
#  'LRP011a' 'LRP013a' 'LRP014a' 'LRP015a' 'LRP029a' 'LRP029c' 'LRP032a'
#  'LRP032b' 'LRP033a' 'LRP034a' 'LRP035a' 'LRP036a' 'LRP037a' 'LRP038a'
#  'LRP039a' 'LRP040a' 'LRP041a' 'LRP042a' 'LRP043a' 'LRP044a' 'LRP045b'
#  'LRP046a' 'LRP047a' 'LRP048b' 'LRP049a' 'LRP050a' 'LRP052a' 'LRP053a'
#  'LRP054a' 'LRP055a' 'LRP056b' 'LRP057b' 'LRP058a' 'LRP058c' 'LRP059a'
#  'LRP060a' 'LRP060c' 'LRP061a']
#
# 50    LRP003
# Name: LRP_before_E, dtype: object
# Road: N503
# Cleaned LRPs: ['LRP001a' 'LRP001c' 'LRP001e' 'LRP002a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001c' 'LRP001e' 'LRP002a']
#
# 60    LRP008a
# Name: LRP_before_E, dtype: object
# Road: N514
# Cleaned LRPs: ['LRP002a' 'LRP005a' 'LRP007a' 'LRP008a']
# Final LRPs: ['LRP005a' 'LRP007a' 'LRP008a']
#
# 63    LRP008
# Name: LRP_before_E, dtype: object
# Road: N517
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP002b' 'LRP003b' 'LRP006b' 'LRPSd']
# Final LRPs: ['LRPSd' 'LRP001a' 'LRP002a' 'LRP002b' 'LRP003b' 'LRP006b']
#
# 64    LRP004b
# Name: LRP_before_E, dtype: object
# Road: N518
# Cleaned LRPs: ['LRP002a' 'LRP003a' 'LRP004a' 'LRPSb' 'LRPSc']
# Final LRPs: ['LRPSb' 'LRPSc' 'LRP002a' 'LRP003a' 'LRP004a']
#
# 68    LRP230b
# Name: LRP_before_E, dtype: object
# Road: N6
# Cleaned LRPs: ['LRP009a' 'LRP013a' 'LRP014a' 'LRP019a' 'LRP019b' 'LRP021a' 'LRP023a'
#  'LRP024a' 'LRP027a' 'LRP029a' 'LRP032a' 'LRP032c' 'LRP035a' 'LRP039a'
#  'LRP039b' 'LRP040a' 'LRP043a' 'LRP043b' 'LRP046b' 'LRP047a' 'LRP047b'
#  'LRP047c' 'LRP048a' 'LRP049a' 'LRP050a' 'LRP052a' 'LRP052b' 'LRP054a'
#  'LRP058a' 'LRP059a' 'LRP060a' 'LRP062a' 'LRP062b' 'LRP063a' 'LRP063b'
#  'LRP064a' 'LRP064b' 'LRP064c' 'LRP065a' 'LRP065b' 'LRP067b' 'LRP069a'
#  'LRP072a' 'LRP072b' 'LRP073a' 'LRP074a' 'LRP075a' 'LRP077a' 'LRP079a'
#  'LRP081a' 'LRP082a' 'LRP083b' 'LRP087a' 'LRP087c' 'LRP088a' 'LRP090a'
#  'LRP093a' 'LRP094a' 'LRP096a' 'LRP097a' 'LRP098a' 'LRP099a' 'LRP100b'
#  'LRP101a' 'LRP103a' 'LRP103b' 'LRP104a' 'LRP105a' 'LRP105b' 'LRP105d'
#  'LRP106a' 'LRP110a' 'LRP111a' 'LRP116a' 'LRP120a' 'LRP121a' 'LRP121b'
#  'LRP122a' 'LRP124a' 'LRP125a' 'LRP125c' 'LRP126a' 'LRP128b' 'LRP129a'
#  'LRP130a' 'LRP130b' 'LRP131b' 'LRP134a' 'LRP135a' 'LRP136a' 'LRP138a'
#  'LRP141a' 'LRP141c' 'LRP142a' 'LRP144a' 'LRP144b' 'LRP145a' 'LRP146a'
#  'LRP146b' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP009a' 'LRP013a' 'LRP014a' 'LRP019a' 'LRP019b' 'LRP021a'
#  'LRP023a' 'LRP024a' 'LRP027a' 'LRP029a' 'LRP032a' 'LRP032c' 'LRP035a'
#  'LRP039a' 'LRP039b' 'LRP040a' 'LRP043a' 'LRP043b' 'LRP046b' 'LRP047a'
#  'LRP047b' 'LRP047c' 'LRP048a' 'LRP049a' 'LRP050a' 'LRP052a' 'LRP052b'
#  'LRP054a' 'LRP058a' 'LRP059a' 'LRP060a' 'LRP062a' 'LRP062b' 'LRP063a'
#  'LRP063b' 'LRP064a' 'LRP064b' 'LRP064c' 'LRP065a' 'LRP065b' 'LRP067b'
#  'LRP069a' 'LRP072a' 'LRP072b' 'LRP073a' 'LRP074a' 'LRP075a' 'LRP077a'
#  'LRP079a' 'LRP081a' 'LRP082a' 'LRP083b' 'LRP087a' 'LRP087c' 'LRP088a'
#  'LRP090a' 'LRP093a' 'LRP094a' 'LRP096a' 'LRP097a' 'LRP098a' 'LRP099a'
#  'LRP100b' 'LRP101a' 'LRP103a' 'LRP103b' 'LRP104a' 'LRP105a' 'LRP105b'
#  'LRP105d' 'LRP106a' 'LRP110a' 'LRP111a' 'LRP116a' 'LRP120a' 'LRP121a'
#  'LRP121b' 'LRP122a' 'LRP124a' 'LRP125a' 'LRP125c' 'LRP126a' 'LRP128b'
#  'LRP129a' 'LRP130a' 'LRP130b' 'LRP131b' 'LRP134a' 'LRP135a' 'LRP136a'
#  'LRP138a' 'LRP141a' 'LRP141c' 'LRP142a' 'LRP144a' 'LRP144b' 'LRP145a'
#  'LRP146a' 'LRP146b']
#
# 70    LRP021
# Name: LRP_before_E, dtype: object
# Road: N603
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002a' 'LRP002b' 'LRP003a' 'LRP003b' 'LRP004a'
#  'LRP004b' 'LRP004c' 'LRP005a' 'LRP005b' 'LRP005c' 'LRP005d' 'LRP006a'
#  'LRP006b' 'LRP006c' 'LRP006d' 'LRP007a' 'LRP007b' 'LRP007c' 'LRP007d'
#  'LRP008a' 'LRP008b' 'LRP008c' 'LRP009a' 'LRP009c' 'LRP009d' 'LRP009e'
#  'LRP010a' 'LRP010b' 'LRP011a' 'LRP011c' 'LRP011d' 'LRP012a' 'LRP012b'
#  'LRP012c' 'LRP013a' 'LRP013b' 'LRP013d' 'LRP014a' 'LRP014b' 'LRP014c'
#  'LRP014d' 'LRP015a' 'LRP015b' 'LRP015c' 'LRP015d' 'LRP016a' 'LRP016b'
#  'LRP016c' 'LRP016d' 'LRP017a' 'LRP017b' 'LRP017c' 'LRP017d' 'LRP018a'
#  'LRP018b' 'LRP018c' 'LRP019a' 'LRP019b' 'LRP019c' 'LRP020b' 'LRP020c'
#  'LRPSa' 'LRPSb' 'LRPSc']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRPSc' 'LRP001a' 'LRP001b' 'LRP002a' 'LRP002b' 'LRP003a'
#  'LRP003b' 'LRP004a' 'LRP004b' 'LRP004c' 'LRP005a' 'LRP005b' 'LRP005c'
#  'LRP005d' 'LRP006a' 'LRP006b' 'LRP006c' 'LRP006d' 'LRP007a' 'LRP007b'
#  'LRP007c' 'LRP007d' 'LRP008a' 'LRP008b' 'LRP008c' 'LRP009a' 'LRP009c'
#  'LRP009d' 'LRP009e' 'LRP010a' 'LRP010b' 'LRP011a' 'LRP011c' 'LRP011d'
#  'LRP012a' 'LRP012b' 'LRP012c' 'LRP013a' 'LRP013b' 'LRP013d' 'LRP014a'
#  'LRP014b' 'LRP014c' 'LRP014d' 'LRP015a' 'LRP015b' 'LRP015c' 'LRP015d'
#  'LRP016a' 'LRP016b' 'LRP016c' 'LRP016d' 'LRP017a' 'LRP017b' 'LRP017c'
#  'LRP017d' 'LRP018a' 'LRP018b' 'LRP018c' 'LRP019a' 'LRP019b' 'LRP019c'
#  'LRP020b' 'LRP020c']
#
# 71    LRP008a
# Name: LRP_before_E, dtype: object
# Road: N604
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP002b' 'LRP004b' 'LRP005a' 'LRP006a' 'LRP007a'
#  'LRPSa' 'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP001a' 'LRP002a' 'LRP002b' 'LRP004b' 'LRP005a'
#  'LRP006a' 'LRP007a']
#
# 76    LRP003a
# Name: LRP_before_E, dtype: object
# Road: N703
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRPSa' 'LRPSc' 'LRPSd' 'LRPSf']
# Final LRPs: ['LRPSa' 'LRPSc' 'LRPSd' 'LRPSf' 'LRP001a' 'LRP001b']
#
# 77    LRP081b
# Name: LRP_before_E, dtype: object
# Road: N704
# Cleaned LRPs: ['LRP003a' 'LRP004a' 'LRP005a' 'LRP007a' 'LRP009a' 'LRP011a' 'LRP012a'
#  'LRP012b' 'LRP012c' 'LRP012d' 'LRP014a' 'LRP014c' 'LRP016a' 'LRP018a'
#  'LRP019a' 'LRP020a' 'LRP024a' 'LRP025a' 'LRP026a' 'LRP027a' 'LRP027b'
#  'LRP028a' 'LRP029a' 'LRP029b' 'LRP032a' 'LRP032b' 'LRP033a' 'LRP033b'
#  'LRP035a' 'LRP035b' 'LRP037a' 'LRP038a' 'LRP039a' 'LRP042a' 'LRP043a'
#  'LRP043b' 'LRP043c' 'LRP044a' 'LRP045a' 'LRP048a' 'LRP049a' 'LRP051a'
#  'LRP053a' 'LRP054a' 'LRP066e' 'LRP067a' 'LRP067b' 'LRP068a' 'LRP068b'
#  'LRP068c' 'LRP068d' 'LRP068e' 'LRP069b' 'LRP070a' 'LRP070b' 'LRP071a'
#  'LRP072a' 'LRP073b' 'LRP074b' 'LRP075b' 'LRP076a' 'LRP076b' 'LRP077a'
#  'LRP077b' 'LRP078a' 'LRP079a' 'LRP079b' 'LRP080a' 'LRP081a' 'LRP081b'
#  'LRP082a']
# Final LRPs: ['LRP003a' 'LRP011a' 'LRP012a' 'LRP012b' 'LRP012d' 'LRP014a' 'LRP014c'
#  'LRP018a' 'LRP019a' 'LRP020a' 'LRP024a' 'LRP025a' 'LRP026a' 'LRP027a'
#  'LRP028a' 'LRP029a' 'LRP029b' 'LRP032a' 'LRP032b' 'LRP033a' 'LRP035a'
#  'LRP037a' 'LRP038a' 'LRP039a' 'LRP043b' 'LRP043c' 'LRP045a' 'LRP048a'
#  'LRP049a' 'LRP054a' 'LRP066e' 'LRP067a' 'LRP067b' 'LRP068a' 'LRP068b'
#  'LRP068c' 'LRP068d' 'LRP068e' 'LRP069b' 'LRP070a' 'LRP070b' 'LRP071a'
#  'LRP072a' 'LRP073b' 'LRP074b' 'LRP075b' 'LRP076a' 'LRP076b' 'LRP077a'
#  'LRP077b' 'LRP078a' 'LRP079a' 'LRP079b' 'LRP080a' 'LRP081a' 'LRP081b']
#
# 81    LRP006
# Name: LRP_before_E, dtype: object
# Road: N708
# Cleaned LRPs: ['LRP001a' 'LRP003b' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP003b']
#
# 84    LRP003c
# Name: LRP_before_E, dtype: object
# Road: N711
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP001d' 'LRPSc' 'LRPSd']
# Final LRPs: ['LRPSc' 'LRPSd' 'LRP001a' 'LRP001b' 'LRP001d']
#
# 91    LRP033
# Name: LRP_before_E, dtype: object
# Road: N804
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP003a' 'LRP003c' 'LRP003e' 'LRP004a' 'LRP005b'
#  'LRP008a' 'LRP010a' 'LRP010c' 'LRP012a' 'LRP012b' 'LRP014a' 'LRP017a'
#  'LRP019a' 'LRP019c' 'LRP020a' 'LRP021a' 'LRP022a' 'LRP024a' 'LRP024b'
#  'LRP026a' 'LRP027a' 'LRP027c' 'LRP028a' 'LRP029a' 'LRP029b' 'LRP030b'
#  'LRP031a' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP001a' 'LRP002a' 'LRP003a' 'LRP003c' 'LRP003e' 'LRP004a'
#  'LRP005b' 'LRP008a' 'LRP010a' 'LRP010c' 'LRP012a' 'LRP012b' 'LRP014a'
#  'LRP017a' 'LRP019a' 'LRP019c' 'LRP020a' 'LRP021a' 'LRP022a' 'LRP024a'
#  'LRP024b' 'LRP026a' 'LRP027a' 'LRP027c' 'LRP028a' 'LRP029a' 'LRP029b'
#  'LRP030b' 'LRP031a']
#
# 92    LRP109a
# Name: LRP_before_E, dtype: object
# Road: N805
# Cleaned LRPs: ['LRP001a' 'LRP001c' 'LRP002a' 'LRP002b' 'LRP003a' 'LRP003c' 'LRP004a'
#  'LRP004c' 'LRP005a' 'LRP005c' 'LRP006a' 'LRP006b' 'LRP006d' 'LRP007a'
#  'LRP007b' 'LRP008a' 'LRP008c' 'LRP009a' 'LRP009b' 'LRP009c' 'LRP010a'
#  'LRP011b' 'LRP011c' 'LRP011d' 'LRP012a' 'LRP012c' 'LRP012d' 'LRP013a'
#  'LRP013c' 'LRP014a' 'LRP014c' 'LRP015a' 'LRP015b' 'LRP016a' 'LRP016c'
#  'LRP017a' 'LRP018b' 'LRP019a' 'LRP019b' 'LRP020a' 'LRP021a' 'LRP021c'
#  'LRP021d' 'LRP022a' 'LRP023a' 'LRP023b' 'LRP023c' 'LRP024a' 'LRP024d'
#  'LRP024e' 'LRP025a' 'LRP026b' 'LRP027a' 'LRP027b' 'LRP028a' 'LRP028c'
#  'LRP029a' 'LRP029b' 'LRP029c' 'LRP030a' 'LRP030b' 'LRP031a' 'LRP031b'
#  'LRP032a' 'LRP032b' 'LRP033a' 'LRP034b' 'LRP034c' 'LRP034d' 'LRP035a'
#  'LRP036a' 'LRP036c' 'LRP037a' 'LRP038a' 'LRP039a' 'LRP040a' 'LRP043a'
#  'LRP045a' 'LRP045b' 'LRP045c' 'LRP047a' 'LRP047b' 'LRP048a' 'LRP048b'
#  'LRP048d' 'LRP049a' 'LRP049b' 'LRP049c' 'LRP050a' 'LRP050b' 'LRP051a'
#  'LRP051b' 'LRP052a' 'LRP053a' 'LRP054a' 'LRP055a' 'LRP055c' 'LRP057a'
#  'LRP057b' 'LRP058a' 'LRP058b' 'LRP059a' 'LRP060a' 'LRP061a' 'LRP062a'
#  'LRP063a' 'LRP063c' 'LRP064a' 'LRP064c' 'LRP065a' 'LRP066a' 'LRP068a'
#  'LRP068b' 'LRP069a' 'LRP071a' 'LRP072a' 'LRP072c' 'LRP072e' 'LRP073a'
#  'LRP075a' 'LRP076a' 'LRP079a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001c' 'LRP002a' 'LRP002b' 'LRP003a' 'LRP003c'
#  'LRP004a' 'LRP004c' 'LRP005a' 'LRP005c' 'LRP006a' 'LRP006b' 'LRP006d'
#  'LRP007a' 'LRP007b' 'LRP008a' 'LRP008c' 'LRP009a' 'LRP009b' 'LRP009c'
#  'LRP010a' 'LRP011b' 'LRP011c' 'LRP011d' 'LRP012a' 'LRP012c' 'LRP012d'
#  'LRP013a' 'LRP013c' 'LRP014a' 'LRP014c' 'LRP015a' 'LRP015b' 'LRP016a'
#  'LRP016c' 'LRP017a' 'LRP018b' 'LRP019a' 'LRP019b' 'LRP020a' 'LRP021a'
#  'LRP021c' 'LRP021d' 'LRP022a' 'LRP023a' 'LRP023b' 'LRP023c' 'LRP024a'
#  'LRP024d' 'LRP024e' 'LRP025a' 'LRP026b' 'LRP027a' 'LRP027b' 'LRP028a'
#  'LRP028c' 'LRP029a' 'LRP029b' 'LRP029c' 'LRP030a' 'LRP030b' 'LRP031a'
#  'LRP031b' 'LRP032a' 'LRP032b' 'LRP033a' 'LRP034b' 'LRP034c' 'LRP034d'
#  'LRP035a' 'LRP036a' 'LRP036c' 'LRP037a' 'LRP038a' 'LRP039a' 'LRP040a'
#  'LRP043a' 'LRP045a' 'LRP045b' 'LRP045c' 'LRP047a' 'LRP047b' 'LRP048a'
#  'LRP048b' 'LRP048d' 'LRP049a' 'LRP049b' 'LRP049c' 'LRP050a' 'LRP050b'
#  'LRP051a' 'LRP051b' 'LRP052a' 'LRP053a' 'LRP054a' 'LRP055a' 'LRP055c'
#  'LRP057a' 'LRP057b' 'LRP058a' 'LRP058b' 'LRP059a' 'LRP060a' 'LRP061a'
#  'LRP062a' 'LRP063a' 'LRP063c' 'LRP064a' 'LRP064c' 'LRP065a' 'LRP066a'
#  'LRP068a' 'LRP068b' 'LRP069a' 'LRP071a' 'LRP072a' 'LRP072c' 'LRP072e'
#  'LRP073a' 'LRP075a' 'LRP076a' 'LRP079a']
#
# 95    LRP067a
# Name: LRP_before_E, dtype: object
# Road: N809
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002a' 'LRP004a' 'LRP004b' 'LRP006a' 'LRP006b'
#  'LRP007a' 'LRP008a' 'LRP009a' 'LRP010a' 'LRP011a' 'LRP012a' 'LRP012b'
#  'LRP013a' 'LRP013b' 'LRP013d' 'LRP014a' 'LRP014b' 'LRP015a' 'LRP015b'
#  'LRP026a' 'LRP028a' 'LRP030a' 'LRP030b' 'LRP032a' 'LRP033a' 'LRP034a'
#  'LRP036a' 'LRP037a' 'LRP038a' 'LRP039a' 'LRP062a' 'LRP062b' 'LRP062c'
#  'LRP063a' 'LRP063b' 'LRP064a' 'LRP064b' 'LRP064e' 'LRP066a' 'LRP066d'
#  'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001b' 'LRP002a' 'LRP004a' 'LRP004b' 'LRP006a'
#  'LRP006b' 'LRP007a' 'LRP008a' 'LRP009a' 'LRP010a' 'LRP011a' 'LRP012a'
#  'LRP012b' 'LRP013a' 'LRP013b' 'LRP013d' 'LRP014a' 'LRP014b' 'LRP015a'
#  'LRP015b' 'LRP026a' 'LRP028a' 'LRP030a' 'LRP030b' 'LRP032a' 'LRP033a'
#  'LRP034a' 'LRP036a' 'LRP037a' 'LRP038a' 'LRP039a' 'LRP062a' 'LRP062b'
#  'LRP062c' 'LRP063a' 'LRP063b' 'LRP064a' 'LRP064b' 'LRP064e' 'LRP066a'
#  'LRP066d']
#
# 97    LRP008
# Name: LRP_before_E, dtype: object
# Road: R111
# Cleaned LRPs: ['LRP002a' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP002a']
#
# 99    LRP011a
# Name: LRP_before_E, dtype: object
# Road: R113
# Cleaned LRPs: ['LRP002a' 'LRP004a' 'LRP006a' 'LRP007a' 'LRP007b' 'LRP010a' 'LRP011a'
#  'LRP012a' 'LRPSa']
# Final LRPs: ['LRP002a' 'LRP006a' 'LRP007a' 'LRP007b' 'LRP011a']
#
# 103    LRP037e
# Name: LRP_before_E, dtype: object
# Road: R141
# Cleaned LRPs: ['LRP001a' 'LRP001d' 'LRP003a' 'LRP004a' 'LRP006a' 'LRP009a' 'LRP010a'
#  'LRP010c' 'LRP012a' 'LRP012b' 'LRP012c' 'LRP013a' 'LRP013c' 'LRP013d'
#  'LRP013f' 'LRP014a' 'LRP014c' 'LRP014e' 'LRP015a' 'LRP017a' 'LRP018a'
#  'LRP020a' 'LRP020b' 'LRP021a' 'LRP022a' 'LRP024a' 'LRP024b' 'LRP026a'
#  'LRP027a' 'LRP029a' 'LRP030a' 'LRP030b' 'LRP031a' 'LRP032a' 'LRP033a'
#  'LRP034a' 'LRP035a' 'LRP037b' 'LRP037c' 'LRP038a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001d' 'LRP003a' 'LRP004a' 'LRP006a' 'LRP009a'
#  'LRP010a' 'LRP010c' 'LRP012a' 'LRP012b' 'LRP012c' 'LRP013a' 'LRP013c'
#  'LRP013d' 'LRP013f' 'LRP014a' 'LRP014c' 'LRP014e' 'LRP015a' 'LRP017a'
#  'LRP018a' 'LRP020a' 'LRP020b' 'LRP021a' 'LRP022a' 'LRP024a' 'LRP024b'
#  'LRP026a' 'LRP027a' 'LRP029a' 'LRP030a' 'LRP030b' 'LRP031a' 'LRP032a'
#  'LRP033a' 'LRP034a' 'LRP035a' 'LRP037b' 'LRP037c' 'LRP038a']
#
# 104    LRP038a
# Name: LRP_before_E, dtype: object
# Road: R142
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP003a' 'LRP003c' 'LRP004a' 'LRP005a' 'LRP006a'
#  'LRP008a' 'LRP008c' 'LRP009a' 'LRP010c' 'LRP010e' 'LRP013a' 'LRP015a'
#  'LRP016a' 'LRP021a' 'LRP022a' 'LRP023b' 'LRP025b' 'LRP027a' 'LRP029a'
#  'LRP031b' 'LRP033a' 'LRP033b' 'LRP035a' 'LRP035d' 'LRP036a' 'LRP037a'
#  'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP002a' 'LRP003a' 'LRP003c' 'LRP004a' 'LRP005a'
#  'LRP006a' 'LRP008a' 'LRP008c' 'LRP009a' 'LRP010c' 'LRP010e' 'LRP013a'
#  'LRP015a' 'LRP016a' 'LRP021a' 'LRP022a' 'LRP023b' 'LRP025b' 'LRP027a'
#  'LRP029a' 'LRP031b' 'LRP033a' 'LRP033b' 'LRP035a' 'LRP035d' 'LRP036a'
#  'LRP037a']
#
# 105    LRP020b
# Name: LRP_before_E, dtype: object
# Road: R143
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002a' 'LRP003a' 'LRP003b' 'LRP004a' 'LRP004b'
#  'LRP006a' 'LRP006b' 'LRP007a' 'LRP008a' 'LRP009a' 'LRP009b' 'LRP013b'
#  'LRP014a' 'LRP015a' 'LRP016c' 'LRP017a' 'LRP017b' 'LRP019a' 'LRP019b'
#  'LRP020b' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001b' 'LRP002a' 'LRP003a' 'LRP003b' 'LRP004a'
#  'LRP004b' 'LRP006a' 'LRP006b' 'LRP007a' 'LRP008a' 'LRP009a' 'LRP009b'
#  'LRP013b' 'LRP014a' 'LRP015a' 'LRP016c' 'LRP017a' 'LRP017b' 'LRP019a'
#  'LRP019b' 'LRP020b']
#
# 110    LRP036b
# Name: LRP_before_E, dtype: object
# Road: R152
# Cleaned LRPs: ['LRP003a' 'LRP006a' 'LRP007a' 'LRP008a' 'LRP008c' 'LRP010a' 'LRP010c'
#  'LRP011b' 'LRP012a' 'LRP013a' 'LRP014a' 'LRP015a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP003a' 'LRP006a' 'LRP007a' 'LRP008a' 'LRP008c' 'LRP010a'
#  'LRP010c' 'LRP011b' 'LRP012a' 'LRP013a' 'LRP014a' 'LRP015a']
#
# 111    LRP093
# Name: LRP_before_E, dtype: object
# Road: R160
# Cleaned LRPs: ['LRP001a' 'LRP001c' 'LRP002a' 'LRP003a' 'LRP003b' 'LRP003d' 'LRP004a'
#  'LRP004c' 'LRP004d' 'LRP005a' 'LRP005b' 'LRP006a' 'LRP006b' 'LRP006c'
#  'LRP006d' 'LRP007a' 'LRP007b' 'LRP007c' 'LRP008a' 'LRP008b' 'LRP008c'
#  'LRP008e' 'LRP008g' 'LRP009a' 'LRP009c' 'LRP010a' 'LRP010b' 'LRP011a'
#  'LRP012b' 'LRP013b' 'LRP014a' 'LRP015a' 'LRP017c' 'LRP018a' 'LRP019a'
#  'LRP019b' 'LRP020a' 'LRP022b' 'LRP023b' 'LRP023d' 'LRP024b' 'LRP026a'
#  'LRP026b' 'LRP027a' 'LRP028a' 'LRP030a' 'LRP031a' 'LRP031d' 'LRP032a'
#  'LRP035a' 'LRP036a' 'LRP038b' 'LRP040a' 'LRP041a' 'LRP041b' 'LRP042a'
#  'LRP043b' 'LRP043c' 'LRP044a' 'LRP044c' 'LRP044d' 'LRP046a' 'LRP046b'
#  'LRP047a' 'LRP047c' 'LRP047e' 'LRP048b' 'LRP056a' 'LRP056c' 'LRP057a'
#  'LRP058a' 'LRP058e' 'LRP059a' 'LRP060a' 'LRP065b' 'LRP066a' 'LRP067a'
#  'LRP070a' 'LRP071a' 'LRP071b' 'LRP071c' 'LRP072a' 'LRP072b' 'LRP074a'
#  'LRP076a' 'LRP076c' 'LRP076d' 'LRP076e' 'LRP077a' 'LRP077c' 'LRP078a'
#  'LRP079a' 'LRP079b' 'LRP085b' 'LRP088a' 'LRP088b' 'LRP088c' 'LRP088d'
#  'LRP088e' 'LRP089a' 'LRP089b' 'LRP089c' 'LRP089d' 'LRP090a' 'LRP090b'
#  'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001c' 'LRP002a' 'LRP003a' 'LRP003b' 'LRP003d'
#  'LRP004a' 'LRP004c' 'LRP004d' 'LRP005a' 'LRP005b' 'LRP006a' 'LRP006b'
#  'LRP006c' 'LRP006d' 'LRP007a' 'LRP007b' 'LRP007c' 'LRP008a' 'LRP008b'
#  'LRP008c' 'LRP008e' 'LRP008g' 'LRP009a' 'LRP009c' 'LRP010a' 'LRP010b'
#  'LRP011a' 'LRP012b' 'LRP013b' 'LRP014a' 'LRP015a' 'LRP017c' 'LRP018a'
#  'LRP019a' 'LRP019b' 'LRP020a' 'LRP022b' 'LRP023b' 'LRP023d' 'LRP024b'
#  'LRP026a' 'LRP026b' 'LRP027a' 'LRP028a' 'LRP030a' 'LRP031a' 'LRP031d'
#  'LRP032a' 'LRP035a' 'LRP036a' 'LRP038b' 'LRP040a' 'LRP041a' 'LRP041b'
#  'LRP042a' 'LRP043b' 'LRP043c' 'LRP044a' 'LRP044c' 'LRP044d' 'LRP046a'
#  'LRP046b' 'LRP047a' 'LRP047c' 'LRP047e' 'LRP048b' 'LRP056a' 'LRP056c'
#  'LRP057a' 'LRP058a' 'LRP058e' 'LRP059a' 'LRP060a' 'LRP065b' 'LRP066a'
#  'LRP067a' 'LRP070a' 'LRP071a' 'LRP071b' 'LRP071c' 'LRP072a' 'LRP072b'
#  'LRP074a' 'LRP076a' 'LRP076c' 'LRP076d' 'LRP076e' 'LRP077a' 'LRP077c'
#  'LRP078a' 'LRP079a' 'LRP079b' 'LRP085b' 'LRP088a' 'LRP088b' 'LRP088c'
#  'LRP088d' 'LRP088e' 'LRP089a' 'LRP089b' 'LRP089c' 'LRP089d' 'LRP090a'
#  'LRP090b']
#
# 113    LRP061a
# Name: LRP_before_E, dtype: object
# Road: R162
# Cleaned LRPs: ['LRP011a' 'LRP019a' 'LRP023a' 'LRP024a' 'LRP027a' 'LRP029a' 'LRP032a'
#  'LRP033a' 'LRP035a' 'LRP037a' 'LRP038a' 'LRP039a' 'LRP040a' 'LRP041a'
#  'LRP042a' 'LRP044a' 'LRP045a' 'LRP046a' 'LRP046b' 'LRP050a' 'LRP052a'
#  'LRP052c' 'LRP053a' 'LRP053b' 'LRP054a' 'LRP056a' 'LRP058a' 'LRP059a'
#  'LRP060a' 'LRP061a' 'LRP062a' 'LRP062c' 'LRP063a' 'LRP064a' 'LRP064b']
# Final LRPs: ['LRP011a' 'LRP019a' 'LRP024a' 'LRP035a' 'LRP037a' 'LRP038a' 'LRP041a'
#  'LRP042a' 'LRP044a' 'LRP046a' 'LRP046b' 'LRP050a' 'LRP052a' 'LRP052c'
#  'LRP053a' 'LRP053b' 'LRP054a' 'LRP056a' 'LRP058a' 'LRP059a' 'LRP060a'
#  'LRP061a']
#
# 114    LRP033
# Name: LRP_before_E, dtype: object
# Road: R163
# Cleaned LRPs: ['LRP001b' 'LRP004a' 'LRP005a' 'LRP011a' 'LRP013a' 'LRP015b' 'LRP022a'
#  'LRP025a' 'LRP026a' 'LRP026c' 'LRP027a' 'LRP028b' 'LRP031a' 'LRPSc']
# Final LRPs: ['LRPSc' 'LRP001b' 'LRP004a' 'LRP005a' 'LRP011a' 'LRP013a' 'LRP015b'
#  'LRP022a' 'LRP025a' 'LRP026a' 'LRP026c' 'LRP027a' 'LRP028b' 'LRP031a']
#
# 115    LRP010
# Name: LRP_before_E, dtype: object
# Road: R164
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP001c' 'LRP001d' 'LRP002a' 'LRP002b' 'LRP003a'
#  'LRP003b' 'LRP003c' 'LRP003d' 'LRP004a' 'LRP004b' 'LRP004c' 'LRP005a'
#  'LRP005c' 'LRP005d' 'LRP006a' 'LRP006c' 'LRP008a' 'LRP008b' 'LRP008c'
#  'LRP008d' 'LRP008e' 'LRPSa' 'LRPSb' 'LRPSc']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRPSc' 'LRP001a' 'LRP001b' 'LRP001c' 'LRP001d' 'LRP002a'
#  'LRP002b' 'LRP003a' 'LRP003b' 'LRP003c' 'LRP003d' 'LRP004a' 'LRP004b'
#  'LRP004c' 'LRP005a' 'LRP005c' 'LRP005d' 'LRP006a' 'LRP006c' 'LRP008a'
#  'LRP008b' 'LRP008c' 'LRP008d' 'LRP008e']
#
# 116    LRP075d
# Name: LRP_before_E, dtype: object
# Road: R170
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP002b' 'LRP002c' 'LRP002e' 'LRP002f' 'LRP003a'
#  'LRP003c' 'LRP004a' 'LRP004b' 'LRP005a' 'LRP005b' 'LRP008b' 'LRP011a'
#  'LRP011b' 'LRP011c' 'LRP011e' 'LRP012a' 'LRP013a' 'LRP015a' 'LRP015c'
#  'LRP016a' 'LRP016d' 'LRP017a' 'LRP018a' 'LRP018b' 'LRP019a' 'LRP023a'
#  'LRP024a' 'LRP025a' 'LRP025b' 'LRP025c' 'LRP026a' 'LRP027a' 'LRP028a'
#  'LRP028b' 'LRP029a' 'LRP029b' 'LRP030a' 'LRP030b' 'LRP031a' 'LRP031c'
#  'LRP031d' 'LRP032a' 'LRP032b' 'LRP032c' 'LRP032d' 'LRP033a' 'LRP033b'
#  'LRP034a' 'LRP034b' 'LRP035a' 'LRP035b' 'LRP036a' 'LRP036b' 'LRP036c'
#  'LRP037b' 'LRP037d' 'LRP037g' 'LRP038a' 'LRP039a' 'LRP039b' 'LRP040a'
#  'LRP041a' 'LRP041b' 'LRP041c' 'LRP042a' 'LRP042b' 'LRP043b' 'LRP043c'
#  'LRP044a' 'LRP044b' 'LRP045b' 'LRP046a' 'LRP046b' 'LRP047a' 'LRP047c'
#  'LRP047d' 'LRP048a' 'LRP049a' 'LRP049b' 'LRP050a' 'LRP050c' 'LRP051a'
#  'LRP052a' 'LRP052c' 'LRP052d' 'LRP053a' 'LRP054c' 'LRP054e' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP002a' 'LRP002b' 'LRP002c' 'LRP002e' 'LRP002f'
#  'LRP003a' 'LRP003c' 'LRP004a' 'LRP004b' 'LRP005a' 'LRP005b' 'LRP008b'
#  'LRP011a' 'LRP011b' 'LRP011c' 'LRP011e' 'LRP012a' 'LRP013a' 'LRP015a'
#  'LRP015c' 'LRP016a' 'LRP016d' 'LRP017a' 'LRP018a' 'LRP018b' 'LRP019a'
#  'LRP023a' 'LRP024a' 'LRP025a' 'LRP025b' 'LRP025c' 'LRP026a' 'LRP027a'
#  'LRP028a' 'LRP028b' 'LRP029a' 'LRP029b' 'LRP030a' 'LRP030b' 'LRP031a'
#  'LRP031c' 'LRP031d' 'LRP032a' 'LRP032b' 'LRP032c' 'LRP032d' 'LRP033a'
#  'LRP033b' 'LRP034a' 'LRP034b' 'LRP035a' 'LRP035b' 'LRP036a' 'LRP036b'
#  'LRP036c' 'LRP037b' 'LRP037d' 'LRP037g' 'LRP038a' 'LRP039a' 'LRP039b'
#  'LRP040a' 'LRP041a' 'LRP041b' 'LRP041c' 'LRP042a' 'LRP042b' 'LRP043b'
#  'LRP043c' 'LRP044a' 'LRP044b' 'LRP045b' 'LRP046a' 'LRP046b' 'LRP047a'
#  'LRP047c' 'LRP047d' 'LRP048a' 'LRP049a' 'LRP049b' 'LRP050a' 'LRP050c'
#  'LRP051a' 'LRP052a' 'LRP052c' 'LRP052d' 'LRP053a' 'LRP054c' 'LRP054e']
#
# 117    LRP014d
# Name: LRP_before_E, dtype: object
# Road: R171
# Cleaned LRPs: ['LRP010a' 'LRP010b' 'LRP010c' 'LRP011a' 'LRP011b' 'LRP012a' 'LRP013b'
#  'LRP013c' 'LRP014b' 'LRP015a' 'LRP015b' 'LRP015c' 'LRPSa' 'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP010a' 'LRP010b' 'LRP010c' 'LRP011a' 'LRP011b'
#  'LRP012a' 'LRP013b' 'LRP013c' 'LRP014b' 'LRP015a' 'LRP015b' 'LRP015c']
#
# 119    LRP005a
# Name: LRP_before_E, dtype: object
# Road: R180
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP001d' 'LRP001e' 'LRP001f' 'LRP002a' 'LRP002c'
#  'LRP003a' 'LRP003b' 'LRP003c' 'LRP003d' 'LRP004b' 'LRP005c' 'LRPSa'
#  'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP001a' 'LRP001b' 'LRP001d' 'LRP001e' 'LRP001f'
#  'LRP002a' 'LRP002c' 'LRP003a' 'LRP003b' 'LRP003c' 'LRP003d' 'LRP004b'
#  'LRP005c']
#
# 121    LRP010a
# Name: LRP_before_E, dtype: object
# Road: R202
# Cleaned LRPs: ['LRP002a' 'LRP003b' 'LRP004c' 'LRP005b' 'LRP006b' 'LRP006d' 'LRP006e'
#  'LRPSa']
# Final LRPs: ['LRPSa' 'LRP002a' 'LRP003b' 'LRP004c' 'LRP005b' 'LRP006b' 'LRP006d'
#  'LRP006e']
#
# 122    LRP076
# Name: LRP_before_E, dtype: object
# Road: R203
# Cleaned LRPs: ['LRP001a' 'LRP001c' 'LRP002a' 'LRP003c' 'LRP004a' 'LRP004c' 'LRP005a'
#  'LRP007c' 'LRP008a' 'LRP009b' 'LRP010a' 'LRP011b' 'LRP012a' 'LRP012b'
#  'LRP014a' 'LRP015a' 'LRP018a' 'LRP018d' 'LRP032b' 'LRP033a' 'LRP034a'
#  'LRP034b' 'LRP034c' 'LRP035a' 'LRP036a' 'LRP036b' 'LRP036d' 'LRP037a'
#  'LRP038a' 'LRP038b' 'LRP039a' 'LRP039b' 'LRP039c' 'LRP040a' 'LRP041a'
#  'LRP041b' 'LRP042a' 'LRP042c' 'LRP042e' 'LRP043b' 'LRP043c' 'LRP044a'
#  'LRP045a' 'LRP045b' 'LRP046a' 'LRP046c' 'LRP047a' 'LRP050a' 'LRP050b'
#  'LRP050c' 'LRP051a' 'LRP051b' 'LRP051c' 'LRP052a' 'LRP053a' 'LRP053b'
#  'LRP054a' 'LRP054b' 'LRP054d' 'LRP055a' 'LRP056a' 'LRP056c' 'LRP056d'
#  'LRP057a' 'LRP058a' 'LRP058b' 'LRP058c' 'LRP058f' 'LRP059a' 'LRP059b'
#  'LRP059c' 'LRP060b' 'LRP060c' 'LRP061a' 'LRP062a' 'LRP062b' 'LRP063a'
#  'LRP063c' 'LRP065a' 'LRP066b' 'LRP066d' 'LRPSa' 'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP001a' 'LRP001c' 'LRP002a' 'LRP003c' 'LRP004a'
#  'LRP004c' 'LRP005a' 'LRP007c' 'LRP008a' 'LRP009b' 'LRP010a' 'LRP011b'
#  'LRP012a' 'LRP012b' 'LRP014a' 'LRP015a' 'LRP018a' 'LRP018d' 'LRP032b'
#  'LRP033a' 'LRP034a' 'LRP034b' 'LRP034c' 'LRP035a' 'LRP036a' 'LRP036b'
#  'LRP036d' 'LRP037a' 'LRP038a' 'LRP038b' 'LRP039a' 'LRP039b' 'LRP039c'
#  'LRP040a' 'LRP041a' 'LRP041b' 'LRP042a' 'LRP042c' 'LRP042e' 'LRP043b'
#  'LRP043c' 'LRP044a' 'LRP045a' 'LRP045b' 'LRP046a' 'LRP046c' 'LRP047a'
#  'LRP050a' 'LRP050b' 'LRP050c' 'LRP051a' 'LRP051b' 'LRP051c' 'LRP052a'
#  'LRP053a' 'LRP053b' 'LRP054a' 'LRP054b' 'LRP054d' 'LRP055a' 'LRP056a'
#  'LRP056c' 'LRP056d' 'LRP057a' 'LRP058a' 'LRP058b' 'LRP058c' 'LRP058f'
#  'LRP059a' 'LRP059b' 'LRP059c' 'LRP060b' 'LRP060c' 'LRP061a' 'LRP062a'
#  'LRP062b' 'LRP063a' 'LRP063c' 'LRP065a' 'LRP066b' 'LRP066d']
#
# 123    LRP004b
# Name: LRP_before_E, dtype: object
# Road: R210
# Cleaned LRPs: ['LRP002c' 'LRP003a' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP002c' 'LRP003a']
#
# 124    LRP045a
# Name: LRP_before_E, dtype: object
# Road: R211
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002a' 'LRP003a' 'LRP004a' 'LRP005a' 'LRP006a'
#  'LRP006c' 'LRP007b' 'LRP008a' 'LRP009a' 'LRP013a' 'LRP013b' 'LRP016a'
#  'LRP018a' 'LRP019b' 'LRP019c' 'LRP020a' 'LRP022a' 'LRP022d' 'LRP025a'
#  'LRP025c' 'LRP026a' 'LRP027a' 'LRP030a' 'LRP030c' 'LRP031c' 'LRP031d'
#  'LRP032c' 'LRP033b' 'LRP033c' 'LRP037a' 'LRP039a' 'LRP040a' 'LRP043a'
#  'LRP044a' 'LRP044b' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP001a' 'LRP001b' 'LRP002a' 'LRP003a' 'LRP004a' 'LRP005a'
#  'LRP006a' 'LRP006c' 'LRP007b' 'LRP008a' 'LRP009a' 'LRP013a' 'LRP013b'
#  'LRP016a' 'LRP018a' 'LRP019b' 'LRP019c' 'LRP020a' 'LRP022a' 'LRP022d'
#  'LRP025a' 'LRP025c' 'LRP026a' 'LRP027a' 'LRP030a' 'LRP030c' 'LRP031c'
# ...
#  'LRP011a' 'LRP012a' 'LRP016a' 'LRP017a' 'LRP018b' 'LRP019a' 'LRP019c'
#  'LRP019d' 'LRP020a' 'LRPSa' 'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP001a' 'LRP002a' 'LRP002b' 'LRP004a' 'LRP004b'
#  'LRP005a' 'LRP005c' 'LRP007a' 'LRP007b' 'LRP008a' 'LRP008c' 'LRP009a'
#  'LRP010a' 'LRP010b' 'LRP011a' 'LRP012a' 'LRP016a' 'LRP017a' 'LRP018b'
#  'LRP019a' 'LRP019c' 'LRP019d' 'LRP020a']
#
# 801    LRP006
# Name: LRP_before_E, dtype: object
# Road: Z8038
# Cleaned LRPs: ['LRP002a' 'LRP003a' 'LRP005a' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP002a' 'LRP003a' 'LRP005a']
#
# 804    LRP032a
# Name: LRP_before_E, dtype: object
# Road: Z8044
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP003b' 'LRP004a' 'LRP006a' 'LRP007a' 'LRP007b'
#  'LRP008a' 'LRP009a' 'LRP009b' 'LRP010a' 'LRP010c' 'LRP011a' 'LRP011c'
#  'LRP030a' 'LRP032a']
# Final LRPs: ['LRP001a' 'LRP001b' 'LRP003b' 'LRP004a' 'LRP008a' 'LRP009a' 'LRP010a'
#  'LRP010c' 'LRP011a' 'LRP011c' 'LRP030a' 'LRP032a']
#
# 806    LRP002d
# Name: LRP_before_E, dtype: object
# Road: Z8048
# Cleaned LRPs: ['LRP002a' 'LRP002b' 'LRP003a' 'LRP003b' 'LRP003d' 'LRP003e' 'LRP004a'
#  'LRP004b' 'LRP005a' 'LRP005c' 'LRP005d' 'LRP006a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP002a' 'LRP002b' 'LRP003a' 'LRP003b' 'LRP003d' 'LRP003e'
#  'LRP004a' 'LRP004b' 'LRP005a' 'LRP005c' 'LRP005d' 'LRP006a']
#
# 809    LRP026a
# Name: LRP_before_E, dtype: object
# Road: Z8052
# Cleaned LRPs: ['LRP002a' 'LRP003a' 'LRP003b' 'LRP004a' 'LRP006a' 'LRP007a' 'LRP008a'
#  'LRP009a' 'LRP009c' 'LRP009d' 'LRP013b' 'LRP015a' 'LRP017a' 'LRP017c'
#  'LRP026b' 'LRP042c' 'LRPSa' 'LRPSc']
# Final LRPs: ['LRPSa' 'LRPSc' 'LRP002a' 'LRP003a' 'LRP003b' 'LRP004a' 'LRP006a'
#  'LRP007a' 'LRP008a' 'LRP009a' 'LRP009c' 'LRP009d' 'LRP013b' 'LRP015a'
#  'LRP017a' 'LRP017c' 'LRP026b' 'LRP042c']
#
# 811    LRP010
# Name: LRP_before_E, dtype: object
# Road: Z8054
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002b' 'LRP003a' 'LRP003b' 'LRP003c' 'LRP004a'
#  'LRP004b' 'LRP005a' 'LRPSa' 'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP001a' 'LRP001b' 'LRP002b' 'LRP003a' 'LRP003b'
#  'LRP003c' 'LRP004a' 'LRP004b' 'LRP005a']
#
# 815    LRP016
# Name: LRP_before_E, dtype: object
# Road: Z8058
# Cleaned LRPs: ['LRP001a' 'LRP001c' 'LRP001d' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001c' 'LRP001d']
#
# 819    LRP006a
# Name: LRP_before_E, dtype: object
# Road: Z8067
# Cleaned LRPs: ['LRP004a' 'LRP004c' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP004a' 'LRP004c']
#
# 820    LRP036b
# Name: LRP_before_E, dtype: object
# Road: Z8121
# Cleaned LRPs: ['LRP001a' 'LRP002b' 'LRP004a' 'LRP005a' 'LRP006a' 'LRP008a' 'LRP009a'
#  'LRP011a' 'LRP012a' 'LRP012b' 'LRP013a' 'LRP014a' 'LRP020b' 'LRP020d'
#  'LRP021a' 'LRP021b' 'LRP021c' 'LRP021e' 'LRP022a' 'LRP024a' 'LRP026a'
#  'LRP027a' 'LRP027c' 'LRP028a' 'LRP029a' 'LRP030a' 'LRP031a' 'LRP033a'
#  'LRP033b' 'LRP033d' 'LRP034d' 'LRP035a' 'LRP035c' 'LRP035d' 'LRPSa'
#  'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP001a' 'LRP002b' 'LRP004a' 'LRP005a' 'LRP006a'
#  'LRP008a' 'LRP009a' 'LRP011a' 'LRP012a' 'LRP012b' 'LRP013a' 'LRP014a'
#  'LRP020b' 'LRP020d' 'LRP021a' 'LRP021b' 'LRP021c' 'LRP021e' 'LRP022a'
#  'LRP024a' 'LRP026a' 'LRP027a' 'LRP027c' 'LRP028a' 'LRP029a' 'LRP030a'
#  'LRP031a' 'LRP033a' 'LRP033b' 'LRP033d' 'LRP034d' 'LRP035a' 'LRP035c'
#  'LRP035d']
#
# 821    LRP007a
# Name: LRP_before_E, dtype: object
# Road: Z8201
# Cleaned LRPs: ['LRP001d' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001d']
#
# 822    LRP015a
# Name: LRP_before_E, dtype: object
# Road: Z8203
# Cleaned LRPs: ['LRP001a' 'LRP001c' 'LRP002a' 'LRP003a' 'LRP003c' 'LRP004a' 'LRP005a'
#  'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001c' 'LRP002a' 'LRP003a' 'LRP003c' 'LRP004a'
#  'LRP005a']
#
# 823    LRP009b
# Name: LRP_before_E, dtype: object
# Road: Z8204
# Cleaned LRPs: ['LRP005a' 'LRP005c' 'LRP009b' 'LRP009c' 'LRP010a' 'LRP010b']
# Final LRPs: ['LRP005a' 'LRP005c' 'LRP009b']
#
# 824    LRP013a
# Name: LRP_before_E, dtype: object
# Road: Z8205
# Cleaned LRPs: ['LRP003b' 'LRP004a' 'LRP006a' 'LRP006b' 'LRP007a' 'LRP010a' 'LRP011a'
#  'LRP012a' 'LRP013a' 'LRP015b' 'LRP016a' 'LRPSa']
# Final LRPs: ['LRP004a' 'LRP011a' 'LRP013a']
#
# 826    LRP005b
# Name: LRP_before_E, dtype: object
# Road: Z8207
# Cleaned LRPs: ['LRP004a' 'LRP005a' 'LRP005b' 'LRP005c' 'LRP005d' 'LRP005f' 'LRP006a'
#  'LRP007a' 'LRP007c']
# Final LRPs: ['LRP004a' 'LRP005a' 'LRP005b']
#
# 827    LRP004b
# Name: LRP_before_E, dtype: object
# Road: Z8208
# Cleaned LRPs: ['LRP001a' 'LRPSc']
# Final LRPs: ['LRPSc' 'LRP001a']
#
# 829    LRP012
# Name: LRP_before_E, dtype: object
# Road: Z8401
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002a' 'LRP004a' 'LRP007a' 'LRP007c' 'LRP008a'
#  'LRPSa' 'LRPSc']
# Final LRPs: ['LRPSa' 'LRPSc' 'LRP001a' 'LRP001b' 'LRP002a' 'LRP004a' 'LRP007a'
#  'LRP007c' 'LRP008a']
#
# 830    LRP038b
# Name: LRP_before_E, dtype: object
# Road: Z8402
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002a' 'LRP002c' 'LRP003a' 'LRP005a' 'LRP008a'
#  'LRP009a' 'LRP010a' 'LRP022a' 'LRP025a' 'LRP026a' 'LRP028a' 'LRP031a'
#  'LRP032a' 'LRP033b' 'LRP035a' 'LRP038a' 'LRP039a' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP001a' 'LRP001b' 'LRP002a' 'LRP002c' 'LRP003a' 'LRP005a'
#  'LRP008a' 'LRP009a' 'LRP010a' 'LRP022a' 'LRP025a' 'LRP026a' 'LRP028a'
#  'LRP031a' 'LRP032a' 'LRP033b' 'LRP035a' 'LRP038a' 'LRP039a']
#
# 833    LRP012
# Name: LRP_before_E, dtype: object
# Road: Z8412
# Cleaned LRPs: ['LRP002a' 'LRP003a' 'LRP003c' 'LRP004a' 'LRP007a' 'LRP008a' 'LRP009a'
#  'LRP009c' 'LRP010a' 'LRP011a' 'LRPSa' 'LRPSc']
# Final LRPs: ['LRPSa' 'LRPSc' 'LRP002a' 'LRP003a' 'LRP003c' 'LRP004a' 'LRP007a'
#  'LRP008a' 'LRP009a' 'LRP009c' 'LRP010a' 'LRP011a']
#
# 835    LRP007
# Name: LRP_before_E, dtype: object
# Road: Z8416
# Cleaned LRPs: ['LRP003a' 'LRP004a' 'LRPSa' 'LRPSc']
# Final LRPs: ['LRPSa' 'LRPSc' 'LRP003a' 'LRP004a']
#
# 837    LRP006
# Name: LRP_before_E, dtype: object
# Road: Z8420
# Cleaned LRPs: ['LRP004a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP004a']
#
# 842    LRP016
# Name: LRP_before_E, dtype: object
# Road: Z8601
# Cleaned LRPs: ['LRP001a' 'LRP001c' 'LRP002a' 'LRP003a' 'LRP004a' 'LRP005a' 'LRP006a'
#  'LRP007a' 'LRP008a' 'LRP008b' 'LRP009b' 'LRP009c' 'LRP010a' 'LRP012a'
#  'LRP012c' 'LRP013a' 'LRP013c' 'LRP015a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001c' 'LRP002a' 'LRP003a' 'LRP004a' 'LRP005a'
#  'LRP006a' 'LRP007a' 'LRP008a' 'LRP008b' 'LRP009b' 'LRP009c' 'LRP010a'
#  'LRP012a' 'LRP012c' 'LRP013a' 'LRP013c' 'LRP015a']
#
# 843    LRP011
# Name: LRP_before_E, dtype: object
# Road: Z8602
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP001c' 'LRP002a' 'LRP002b' 'LRP003a' 'LRP003b'
#  'LRP004a' 'LRP005a' 'LRP005c' 'LRP005d' 'LRP005f' 'LRP006a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001b' 'LRP001c' 'LRP002a' 'LRP002b' 'LRP003a'
#  'LRP003b' 'LRP004a' 'LRP005a' 'LRP005c' 'LRP005d' 'LRP005f' 'LRP006a']
#
# 846    LRP003a
# Name: LRP_before_E, dtype: object
# Road: Z8605
# Cleaned LRPs: ['LRP002a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP002a']
#
# 850    LRP008a
# Name: LRP_before_E, dtype: object
# Road: Z8699
# Cleaned LRPs: ['LRP001a' 'LRP005a' 'LRP005c' 'LRP006a' 'LRP007c' 'LRP008a' 'LRP008c']
# Final LRPs: ['LRP001a' 'LRP007c' 'LRP008a']
#
# 851    LRP057
# Name: LRP_before_E, dtype: object
# Road: Z8701
# Cleaned LRPs: ['LRP002a' 'LRP002b' 'LRP002c' 'LRP003a' 'LRP003b' 'LRP003c' 'LRP003d'
#  'LRP004a' 'LRP004c' 'LRP006a' 'LRP006c' 'LRP007a' 'LRP007b' 'LRP008a'
#  'LRP008b' 'LRP009a' 'LRP009b' 'LRP010a' 'LRP012a' 'LRP012c' 'LRP014a'
#  'LRP014d' 'LRP015a' 'LRP016a' 'LRP016b' 'LRP018a' 'LRP018c' 'LRP021a'
#  'LRP022a' 'LRP023a' 'LRP023b' 'LRP024a' 'LRP025a' 'LRP026a' 'LRP027a'
#  'LRP028a' 'LRP028d' 'LRP028e' 'LRP029b' 'LRP029c' 'LRP030a' 'LRP030b'
#  'LRP032a' 'LRP032b' 'LRP033a' 'LRP034a' 'LRP034b' 'LRP035a' 'LRP036a'
#  'LRP039a' 'LRP040a' 'LRP041a' 'LRP042a' 'LRP043a' 'LRP045a' 'LRP045c'
#  'LRP046a' 'LRP048a' 'LRP049a' 'LRP051a' 'LRP052a' 'LRP052b' 'LRP053a'
#  'LRP054a' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP002a' 'LRP002b' 'LRP002c' 'LRP003a' 'LRP003b' 'LRP003c'
#  'LRP003d' 'LRP004a' 'LRP004c' 'LRP006a' 'LRP006c' 'LRP007a' 'LRP007b'
#  'LRP008a' 'LRP008b' 'LRP009a' 'LRP009b' 'LRP010a' 'LRP012a' 'LRP012c'
#  'LRP014a' 'LRP014d' 'LRP015a' 'LRP016a' 'LRP016b' 'LRP018a' 'LRP018c'
#  'LRP021a' 'LRP022a' 'LRP023a' 'LRP023b' 'LRP024a' 'LRP025a' 'LRP026a'
#  'LRP027a' 'LRP028a' 'LRP028d' 'LRP028e' 'LRP029b' 'LRP029c' 'LRP030a'
#  'LRP030b' 'LRP032a' 'LRP032b' 'LRP033a' 'LRP034a' 'LRP034b' 'LRP035a'
#  'LRP036a' 'LRP039a' 'LRP040a' 'LRP041a' 'LRP042a' 'LRP043a' 'LRP045a'
#  'LRP045c' 'LRP046a' 'LRP048a' 'LRP049a' 'LRP051a' 'LRP052a' 'LRP052b'
#  'LRP053a' 'LRP054a']
#
# 854    LRP017
# Name: LRP_before_E, dtype: object
# Road: Z8704
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP002a' 'LRP002b' 'LRP002c' 'LRP002d' 'LRP003a'
#  'LRP003b' 'LRP004a' 'LRP004b' 'LRP004c' 'LRP004e' 'LRP005a' 'LRP005b'
#  'LRP005c' 'LRP006a' 'LRP006b' 'LRP006d' 'LRP006e' 'LRP007a' 'LRP007b'
#  'LRP007d' 'LRP008a' 'LRP008b' 'LRP008c' 'LRP009a' 'LRP009c' 'LRP010a'
#  'LRP011a' 'LRP011b' 'LRP011c' 'LRP012a' 'LRP013a' 'LRP013b' 'LRP013c'
#  'LRP014a' 'LRP015a' 'LRP015c' 'LRP015d' 'LRP015e' 'LRP017a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001b' 'LRP002a' 'LRP002b' 'LRP002c' 'LRP002d'
#  'LRP003a' 'LRP003b' 'LRP004a' 'LRP004b' 'LRP004c' 'LRP004e' 'LRP005a'
#  'LRP005b' 'LRP005c' 'LRP006a' 'LRP006b' 'LRP006d' 'LRP006e' 'LRP007a'
#  'LRP007b' 'LRP007d' 'LRP008a' 'LRP008b' 'LRP008c' 'LRP009a' 'LRP009c'
#  'LRP010a' 'LRP011a' 'LRP011b' 'LRP011c' 'LRP012a' 'LRP013a' 'LRP013b'
#  'LRP013c' 'LRP014a' 'LRP015a' 'LRP015c' 'LRP015d' 'LRP015e' 'LRP017a']
#
# 855    LRP011a
# Name: LRP_before_E, dtype: object
# Road: Z8705
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP001c' 'LRP001d' 'LRP002a' 'LRP002b' 'LRP003a'
#  'LRP006a' 'LRP006b' 'LRP007a' 'LRP007b' 'LRP007e' 'LRP008a' 'LRP009a'
#  'LRP010b' 'LRP011a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001b' 'LRP001c' 'LRP001d' 'LRP002a' 'LRP002b'
#  'LRP003a' 'LRP006b' 'LRP007a' 'LRP007b' 'LRP007e' 'LRP008a' 'LRP009a'
#  'LRP010b' 'LRP011a']
#
# 857    LRP074
# Name: LRP_before_E, dtype: object
# Road: Z8708
# Cleaned LRPs: ['LRP001a' 'LRP001c' 'LRP002a' 'LRP003a' 'LRP003c' 'LRP004a' 'LRP004b'
#  'LRP005a' 'LRP005b' 'LRP005d' 'LRP006a' 'LRP006c' 'LRP007a' 'LRP008a'
#  'LRP008c' 'LRP008d' 'LRP009a' 'LRP009b' 'LRP010a' 'LRP010b' 'LRP012b'
#  'LRP013a' 'LRP013b' 'LRP013d' 'LRP014a' 'LRP014c' 'LRP014e' 'LRP014f'
#  'LRP015a' 'LRP015b' 'LRP015c' 'LRP016a' 'LRP017a' 'LRP017b' 'LRP018a'
#  'LRP018d' 'LRP019a' 'LRP019b' 'LRP019c' 'LRP020a' 'LRP021a' 'LRP022a'
#  'LRP022b' 'LRP023b' 'LRP024a' 'LRP024b' 'LRP024c' 'LRP025a' 'LRP025b'
#  'LRP026a' 'LRP027a' 'LRP027c' 'LRP028a' 'LRP028b' 'LRP029a' 'LRP030c'
#  'LRP031a' 'LRP058a' 'LRP060b' 'LRP061a' 'LRP062a' 'LRP063b' 'LRP063c'
#  'LRP064a' 'LRP064b' 'LRP065a' 'LRP065c' 'LRP066a' 'LRP066c' 'LRP067a'
#  'LRP068a' 'LRP069a' 'LRP070a' 'LRP071a' 'LRP071b' 'LRP073a' 'LRP074c'
#  'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP001c' 'LRP002a' 'LRP003a' 'LRP003c' 'LRP004a'
#  'LRP004b' 'LRP005a' 'LRP005b' 'LRP005d' 'LRP006a' 'LRP006c' 'LRP007a'
#  'LRP008a' 'LRP008c' 'LRP008d' 'LRP009a' 'LRP009b' 'LRP010a' 'LRP010b'
#  'LRP012b' 'LRP013a' 'LRP013b' 'LRP013d' 'LRP014a' 'LRP014c' 'LRP014e'
#  'LRP014f' 'LRP015a' 'LRP015b' 'LRP015c' 'LRP016a' 'LRP017a' 'LRP017b'
#  'LRP018a' 'LRP018d' 'LRP019a' 'LRP019b' 'LRP019c' 'LRP020a' 'LRP021a'
#  'LRP022a' 'LRP022b' 'LRP023b' 'LRP024a' 'LRP024b' 'LRP024c' 'LRP025a'
#  'LRP025b' 'LRP026a' 'LRP027a' 'LRP027c' 'LRP028a' 'LRP028b' 'LRP029a'
#  'LRP030c' 'LRP031a' 'LRP058a' 'LRP060b' 'LRP061a' 'LRP062a' 'LRP063b'
#  'LRP063c' 'LRP064a' 'LRP064b' 'LRP065a' 'LRP065c' 'LRP066a' 'LRP066c'
#  'LRP067a' 'LRP068a' 'LRP069a' 'LRP070a' 'LRP071a' 'LRP071b' 'LRP073a'
#  'LRP074c']
#
# Series([], Name: LRP_before_E, dtype: object)
# Road: Z8711
# Cleaned LRPs: ['LRP002a' 'LRP002c' 'LRP003a' 'LRP004a' 'LRP005a' 'LRP005b' 'LRP006a'
#  'LRP006b' 'LRP007a' 'LRP007b' 'LRP008a' 'LRP008c' 'LRPSa' 'LRPSb' 'LRPSc'
#  'LRPSd' 'LRPSe' 'LRPSf']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRPSc' 'LRPSd' 'LRPSe' 'LRPSf' 'LRP002a' 'LRP002c'
#  'LRP003a' 'LRP004a' 'LRP005a' 'LRP005b' 'LRP006a' 'LRP006b' 'LRP007a'
#  'LRP007b' 'LRP008a' 'LRP008c']
#
# 859    LRP016
# Name: LRP_before_E, dtype: object
# Road: Z8713
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP002b' 'LRP002c' 'LRP002d' 'LRP003a' 'LRP003c'
#  'LRP003e' 'LRP003f' 'LRP003h' 'LRP004a' 'LRP004c' 'LRP005a' 'LRP005b'
#  'LRP005c' 'LRP006a' 'LRP007a' 'LRP007b' 'LRP008a' 'LRP008b' 'LRP009a'
#  'LRP009b' 'LRP009d' 'LRP011a' 'LRP011c' 'LRP012a' 'LRP012b' 'LRP013a'
#  'LRP013b' 'LRP013d' 'LRP013e' 'LRP014a' 'LRP015a' 'LRP015b' 'LRPSb']
# Final LRPs: ['LRPSb' 'LRP001a' 'LRP002a' 'LRP002b' 'LRP002c' 'LRP002d' 'LRP003a'
#  'LRP003c' 'LRP003e' 'LRP003f' 'LRP003h' 'LRP004a' 'LRP004c' 'LRP005a'
#  'LRP005b' 'LRP005c' 'LRP006a' 'LRP007a' 'LRP007b' 'LRP008a' 'LRP008b'
#  'LRP009a' 'LRP009b' 'LRP009d' 'LRP011a' 'LRP011c' 'LRP012a' 'LRP012b'
#  'LRP013a' 'LRP013b' 'LRP013d' 'LRP013e' 'LRP014a' 'LRP015a' 'LRP015b']
#
# 861    LRP011a
# Name: LRP_before_E, dtype: object
# Road: Z8717
# Cleaned LRPs: ['LRP001a' 'LRP001b' 'LRP001d' 'LRP002a' 'LRP002b' 'LRP003a' 'LRP003c'
#  'LRP004a' 'LRP005a' 'LRP005c' 'LRP006a' 'LRP006c' 'LRP008a' 'LRP009a'
#  'LRP009c' 'LRPSa' 'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP001a' 'LRP001b' 'LRP001d' 'LRP002a' 'LRP002b'
#  'LRP003a' 'LRP003c' 'LRP004a' 'LRP005a' 'LRP005c' 'LRP006a' 'LRP006c'
#  'LRP008a' 'LRP009a' 'LRP009c']
#
# 866    LRP086
# Name: LRP_before_E, dtype: object
# Road: Z8806
# Cleaned LRPs: ['LRP001a' 'LRP003a' 'LRP003c' 'LRP003d' 'LRP004a' 'LRP005a' 'LRP005b'
#  'LRP006a' 'LRP008a' 'LRP010a' 'LRP011a' 'LRP012a' 'LRP015a' 'LRP015c'
#  'LRP016a' 'LRP016b' 'LRP017a' 'LRP018a' 'LRP021a' 'LRP021b' 'LRP023a'
#  'LRP025a' 'LRP028b' 'LRP029b' 'LRP031a' 'LRP031c' 'LRP032a' 'LRP033a'
#  'LRP033c' 'LRP036a' 'LRP038a' 'LRP040a' 'LRP042a' 'LRP043a' 'LRP043b'
#  'LRP045a' 'LRP046a' 'LRP048a' 'LRP051a' 'LRP054a' 'LRP072a' 'LRP077c'
#  'LRP080a' 'LRP081b' 'LRP082a' 'LRP082b' 'LRP083a' 'LRP084a' 'LRP084b'
#  'LRP085a' 'LRP085b' 'LRPSa' 'LRPSc']
# Final LRPs: ['LRPSa' 'LRPSc' 'LRP001a' 'LRP003a' 'LRP003c' 'LRP003d' 'LRP004a'
#  'LRP005a' 'LRP005b' 'LRP006a' 'LRP008a' 'LRP010a' 'LRP011a' 'LRP012a'
#  'LRP015a' 'LRP015c' 'LRP016a' 'LRP016b' 'LRP017a' 'LRP018a' 'LRP021a'
#  'LRP021b' 'LRP023a' 'LRP025a' 'LRP028b' 'LRP029b' 'LRP031a' 'LRP031c'
#  'LRP032a' 'LRP033a' 'LRP033c' 'LRP036a' 'LRP038a' 'LRP040a' 'LRP042a'
#  'LRP043a' 'LRP043b' 'LRP045a' 'LRP046a' 'LRP048a' 'LRP051a' 'LRP054a'
#  'LRP072a' 'LRP077c' 'LRP080a' 'LRP081b' 'LRP082a' 'LRP082b' 'LRP083a'
#  'LRP084a' 'LRP084b' 'LRP085a' 'LRP085b']
#
# 871    LRP006a
# Name: LRP_before_E, dtype: object
# Road: Z8909
# Cleaned LRPs: ['LRP003a' 'LRP003c' 'LRP004a' 'LRP004c' 'LRP005a' 'LRP005b' 'LRP005d'
#  'LRP006a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP003a' 'LRP003c' 'LRP004a' 'LRP005a' 'LRP005b' 'LRP005d'
#  'LRP006a']
#
# 872    LRP039b
# Name: LRP_before_E, dtype: object
# Road: Z8910
# Cleaned LRPs: ['LRP002a' 'LRP004a' 'LRP005a' 'LRP017b' 'LRP018a' 'LRP019a' 'LRP021a'
#  'LRP023a' 'LRP025a' 'LRP026a' 'LRP028a' 'LRP029a' 'LRP030a' 'LRP033a'
#  'LRP033c' 'LRP034a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP002a' 'LRP004a' 'LRP005a' 'LRP017b' 'LRP018a' 'LRP019a'
#  'LRP021a' 'LRP023a' 'LRP025a' 'LRP026a' 'LRP028a' 'LRP029a' 'LRP030a'
#  'LRP033a' 'LRP033c' 'LRP034a']
#
# 873    LRP025a
# Name: LRP_before_E, dtype: object
# Road: Z8913
# Cleaned LRPs: ['LRP002a' 'LRP003a' 'LRP005a' 'LRP009a' 'LRP009c' 'LRP011a' 'LRP011e'
#  'LRP014a' 'LRP015a' 'LRP017a' 'LRP017b' 'LRP018a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP002a' 'LRP003a' 'LRP005a' 'LRP009a' 'LRP009c' 'LRP011a'
#  'LRP011e' 'LRP014a' 'LRP015a' 'LRP017a' 'LRP017b' 'LRP018a']
#
# 874    LRP016
# Name: LRP_before_E, dtype: object
# Road: Z8915
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP003a' 'LRP006a' 'LRP009a' 'LRP012a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP001a' 'LRP002a' 'LRP003a' 'LRP006a' 'LRP009a' 'LRP012a']
#
# 875    LRP011b
# Name: LRP_before_E, dtype: object
# Road: Z8916
# Cleaned LRPs: ['LRP002a' 'LRP003a' 'LRP007a' 'LRP009a' 'LRPSa']
# Final LRPs: ['LRPSa' 'LRP002a' 'LRP003a' 'LRP007a' 'LRP009a']
#
# 876    LRP008b
# Name: LRP_before_E, dtype: object
# Road: Z8943
# Cleaned LRPs: ['LRP003b' 'LRP004a' 'LRP005a' 'LRP006a' 'LRP006b' 'LRP007a' 'LRP008b'
#  'LRP008c' 'LRP010a' 'LRP010c' 'LRP011a' 'LRP011b' 'LRP011c']
# Final LRPs: ['LRP003b' 'LRP004a' 'LRP005a' 'LRP006a' 'LRP006b' 'LRP007a' 'LRP008b']
#
# Series([], Name: LRP_before_E, dtype: object)
# Road: Z8948
# Cleaned LRPs: ['LRP001a' 'LRP002a' 'LRP002c' 'LRPSa' 'LRPSb']
# Final LRPs: ['LRPSa' 'LRPSb' 'LRP001a' 'LRP002a' 'LRP002c']

# %% [markdown]
# ## Save excel file

# %%
# Save the cleaned data to a new excel file
dir = 'infrastructure/cleaned/'
filename = 'BMMS_overview__cleaned_bridges_after_LPRE_removed.xlsx'
df_final_bridges.to_excel(dir + filename, index=False, sheet_name='BMMS_overview')

# %% [markdown]
# # Adjust lat lon

# %%
df_roads
# Out:
#         road      lrp        lat        lon
# 0         N1     LRPS  23.706028  90.443333
# 1         N1    LRPSa  23.704403  90.446903
# 2         N1    LRPSb  23.702778  90.450472
# 3         N1   LRP001  23.702722  90.455914
# 4         N1   LRP002  23.702667  90.461356
# ...      ...      ...        ...        ...
# 52205  Z8943   LRP007  22.429286  90.783722
# 52206  Z8943   LRP008  22.429768  90.779305
# 52207  Z8943  LRP008a  22.430249  90.774888
# 52208  Z8943  LRP008b  22.430249  90.774860
# 52209  Z8943     LRPE  22.430166  90.768916
#
# [52210 rows x 4 columns]

# %%
df_final_bridges
# Out:
#         road      km                   type  LRPName  \
# 0         N1   1.800            Box Culvert  LRP001a
# 1         N1   4.925            Box Culvert  LRP004b
# 2         N1   8.976       PC Girder Bridge  LRP008b
# 3         N1  10.543            Box Culvert  LRP010a
# 4         N1  10.880            Box Culvert  LRP010b
# ...      ...     ...                    ...      ...
# 17778  Z8948   0.306            Box Culvert    LRPSa
# 17779  Z8948   0.640            Box Culvert    LRPSb
# 17780  Z8948   1.010            Box Culvert  LRP001a
# 17781  Z8948   2.070  Steel Beam & RCC Slab  LRP002a
# 17782  Z8948   2.100  Steel Beam & RCC Slab  LRP002c
#
#                             name  length condition  structureNr  \
# 0                              .    11.3         A       117861
# 1                              .     6.6         A       117862
# 2      KANCHPUR PC GIRDER BRIDGE   397.0         C       101102
# 3           KATCHPUR BOX CULVERT     8.0         B       101106
# 4               NOYAPARA CULVERT     6.3         A       112531
# ...                          ...     ...       ...          ...
# 17778                          .     2.0         A       116832
# 17779                          .     2.0         A       116833
# 17780                          .     2.0         A       116834
# 17781                          .    18.5         A       116835
# 17782                          .    18.5         A       116836
#
#                                                 roadName  chainage  width  \
# 0      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...     1.800  19.50
# 1      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...     4.925  35.40
# 2      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...     8.976  14.65
# 3      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    10.543  21.70
# 4      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    10.880  12.20
# ...                                                  ...       ...    ...
# 17778                           Fakirhat-Khasherhat Road     0.306  10.00
# 17779                           Fakirhat-Khasherhat Road     0.640  10.00
# 17780                           Fakirhat-Khasherhat Road     1.010   9.70
# 17781                           Fakirhat-Khasherhat Road     2.070   3.00
# 17782                           Fakirhat-Khasherhat Road     2.100   3.00
#
#        constructionYear  spans     zone   circle     division   sub-division  \
# 0                2005.0    2.0    Dhaka    Dhaka  Narayanganj  Narayanganj-1
# 1                2006.0    1.0    Dhaka    Dhaka  Narayanganj  Narayanganj-1
# 2                1986.0    8.0    Dhaka    Dhaka  Narayanganj  Narayanganj-1
# 3                1987.0    2.0    Dhaka    Dhaka  Narayanganj      Vitikandi
# 4                1992.0    2.0    Dhaka    Dhaka  Narayanganj      Vitikandi
# ...                 ...    ...      ...      ...          ...            ...
# 17778            1998.0    1.0  Barisal  Barisal        Bhola          Bhola
# 17779            1998.0    1.0  Barisal  Barisal        Bhola          Bhola
# 17780            1995.0    1.0  Barisal  Barisal        Bhola          Bhola
# 17781            1994.0    3.0  Barisal  Barisal        Bhola          Bhola
# 17782            1990.0    3.0  Barisal  Barisal        Bhola          Bhola
#
#              lat        lon EstimatedLoc
# 0      23.702889  90.450389         bcs1
# 1      23.693611  90.478833         bcs1
# 2      23.702083  90.515917         bcs1
# 3      23.702056  90.528194         bcs1
# 4      23.699833  90.530722         bcs1
# ...          ...        ...          ...
# 17778  22.425278  90.787778         bcs1
# 17779  22.422778  90.787222         bcs1
# 17780  22.419167  90.787500         bcs1
# 17781  22.414167  90.791667         bcs1
# 17782  22.414167  90.791944         bcs1
#
# [17783 rows x 20 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point
from scipy.spatial import cKDTree

def adjust_bridge_coordinates_simple(df_bridges, df_roads):
    adjusted_bridges = df_bridges.copy()
    
    for road in df_bridges['road'].unique():
        road_rows = df_roads[df_roads['road'] == road]
        road_points = list(zip(road_rows['lon'], road_rows['lat']))
        if len(road_points) == 0:
            continue
        tree = cKDTree(road_points)
        
        for idx, bridge_row in df_bridges[df_bridges['road'] == road].iterrows():
            bridge_point = (bridge_row['lon'], bridge_row['lat'])
            dist, idx_closest = tree.query(bridge_point)
            closest_point = road_points[idx_closest]
            
            adjusted_bridges.at[idx, 'lat'] = closest_point[1]
            adjusted_bridges.at[idx, 'lon'] = closest_point[0]
    
    return adjusted_bridges

df_final_bridges_adjusted = adjust_bridge_coordinates_simple(df_final_bridges, df_roads)
df_final_bridges_adjusted
# Out:
#         road      km                   type  LRPName  \
# 0         N1   1.800            Box Culvert  LRP001a
# 1         N1   4.925            Box Culvert  LRP004b
# 2         N1   8.976       PC Girder Bridge  LRP008b
# 3         N1  10.543            Box Culvert  LRP010a
# 4         N1  10.880            Box Culvert  LRP010b
# ...      ...     ...                    ...      ...
# 17778  Z8948   0.306            Box Culvert    LRPSa
# 17779  Z8948   0.640            Box Culvert    LRPSb
# 17780  Z8948   1.010            Box Culvert  LRP001a
# 17781  Z8948   2.070  Steel Beam & RCC Slab  LRP002a
# 17782  Z8948   2.100  Steel Beam & RCC Slab  LRP002c
#
#                             name  length condition  structureNr  \
# 0                              .    11.3         A       117861
# 1                              .     6.6         A       117862
# 2      KANCHPUR PC GIRDER BRIDGE   397.0         C       101102
# 3           KATCHPUR BOX CULVERT     8.0         B       101106
# 4               NOYAPARA CULVERT     6.3         A       112531
# ...                          ...     ...       ...          ...
# 17778                          .     2.0         A       116832
# 17779                          .     2.0         A       116833
# 17780                          .     2.0         A       116834
# 17781                          .    18.5         A       116835
# 17782                          .    18.5         A       116836
#
#                                                 roadName  chainage  width  \
# 0      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...     1.800  19.50
# 1      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...     4.925  35.40
# 2      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...     8.976  14.65
# 3      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    10.543  21.70
# 4      Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    10.880  12.20
# ...                                                  ...       ...    ...
# 17778                           Fakirhat-Khasherhat Road     0.306  10.00
# 17779                           Fakirhat-Khasherhat Road     0.640  10.00
# 17780                           Fakirhat-Khasherhat Road     1.010   9.70
# 17781                           Fakirhat-Khasherhat Road     2.070   3.00
# 17782                           Fakirhat-Khasherhat Road     2.100   3.00
#
#        constructionYear  spans     zone   circle     division   sub-division  \
# 0                2005.0    2.0    Dhaka    Dhaka  Narayanganj  Narayanganj-1
# 1                2006.0    1.0    Dhaka    Dhaka  Narayanganj  Narayanganj-1
# 2                1986.0    8.0    Dhaka    Dhaka  Narayanganj  Narayanganj-1
# 3                1987.0    2.0    Dhaka    Dhaka  Narayanganj      Vitikandi
# 4                1992.0    2.0    Dhaka    Dhaka  Narayanganj      Vitikandi
# ...                 ...    ...      ...      ...          ...            ...
# 17778            1998.0    1.0  Barisal  Barisal        Bhola          Bhola
# 17779            1998.0    1.0  Barisal  Barisal        Bhola          Bhola
# 17780            1995.0    1.0  Barisal  Barisal        Bhola          Bhola
# 17781            1994.0    3.0  Barisal  Barisal        Bhola          Bhola
# 17782            1990.0    3.0  Barisal  Barisal        Bhola          Bhola
#
#              lat        lon EstimatedLoc
# 0      23.702778  90.450472         bcs1
# 1      23.702500  90.477683         bcs1
# 2      23.702111  90.515778         bcs1
# 3      23.701528  90.528194         bcs1
# 4      23.699861  90.530722         bcs1
# ...          ...        ...          ...
# 17778  22.425278  90.787778         bcs1
# 17779  22.422778  90.787222         bcs1
# 17780  22.419167  90.787500         bcs1
# 17781  22.414167  90.791667         bcs1
# 17782  22.414167  90.791944         bcs1
#
# [17783 rows x 20 columns]

# %% [markdown]
# ## Save excel file: Final

# %%
# Save the cleaned data to a .xlsx file
dir = 'infrastructure/cleaned/'
filename = 'BMMS_overview_cleaned_final.xlsx'
df_final_bridges_adjusted.to_excel(dir + filename, index=False, sheet_name='BMMS_overview')
