# %% [markdown]
# # Clean Traffic Data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import data

# %%
## Import road traffic data
roads = ['N1', 'N102', 'N104', 'N105', 'N106', 'N2', 'N204', 'N207', 'N208']
traffic_data = {}

file_path = '../data/processed/'

for road in roads:
    file_name = f"{file_path + road + '_traffic'}.csv"  # Assuming each road has a corresponding CSV file named after it
    try:
        traffic_data[road] = pd.read_csv(file_name)
    except FileNotFoundError:
        print(f"File {file_name} not found.")

traffic_data
# Out:
# {'N1':     Link no                                            Name   S_LRP  S_Offset  \
#  0     N1-1L        Jatrabari - Int.with Z1101 (Left) (Left)    LRPS         0
#  1     N1-1R       Jatrabari - Int.with Z1101 (Left) (Right)    LRPS         0
#  2     N1-2L   Int.with Z1101 - Signboard (Left) R111 (Left)    LRPS       822
#  3     N1-2R  Int.with Z1101 - Signboard (Left) R111 (Right)    LRPS       822
#  4     N1-3L          Signboard - Shimrail (Left)R110 (Left)    LRPS      4175
#  ..      ...                                             ...     ...       ...
#  100   N1-65          Coxsbazar Link Road N110-Maricha Z1009  LRP386       724
#  101   N1-66             Maricha Z1009-Ukhia Dakbanglo Z1503  LRP403       217
#  102   N1-67            Ukhia Dakbanglo Z1503 - Gundum Z1504  LRP413       300
#  103   N1-68              GundumGundum Z1504 - Whykong Z1133  LRP420       900
#  104   N1-69                          Whykong Z1133 - Teknaf  LRP433       521
#
#       S_Chainage   E_LRP  E_Offset  E_Chainage  Length (km)  Heavy Truck  ...  \
#  0         0.000    LRPS       822       0.822        0.822        402.0  ...
#  1         0.000    LRPS       822       0.822        0.822        660.0  ...
#  2         0.822    LRPS      4175       4.175        3.353        660.0  ...
#  3         0.822    LRPS      4175       4.175        3.353        402.0  ...
#  4         4.175    LRPS      7181       7.181        3.006         91.0  ...
#  ..          ...     ...       ...         ...          ...          ...  ...
#  100     381.481  LRP403       217     398.205       16.724         24.0  ...
#  101     398.205  LRP413       300     408.434       10.229         24.0  ...
#  102     408.434  LRP420       900     416.044        7.610         24.0  ...
#  103     416.044  LRP433       521     428.908       12.864         24.0  ...
#  104     428.908  LRP467       130     462.254       33.346         24.0  ...
#
#          Car  Auto Rickshaw  Motor Cycle  Bi-Cycle  Cycle Rickshaw  Cart  \
#  0    1851.0         2980.0        398.0     232.0           889.0   0.0
#  1    2608.0         2508.0        436.0     213.0          1088.0   0.0
#  2    2608.0         2508.0        436.0     213.0          1088.0   0.0
#  3    1851.0         2980.0        398.0     232.0           889.0   0.0
#  4    1690.0         2266.0       1087.0      75.0          1198.0   0.0
#  ..      ...            ...          ...       ...             ...   ...
#  100   142.0         2476.0        419.0      97.0          1042.0   0.0
#  101   142.0         2476.0        419.0      97.0          1042.0   0.0
#  102   142.0         2476.0        419.0      97.0          1042.0   0.0
#  103   142.0         2476.0        419.0      97.0          1042.0   0.0
#  104   142.0         2476.0        419.0      97.0          1042.0   0.0
#
#       Motorized  Non Motorized  Total AADT   (AADT)
#  0      18236.0         1121.0     19357.0  19357.0
#  1      20236.0         1301.0     21537.0  21537.0
#  2      20236.0         1301.0     21537.0  21537.0
#  3      18236.0         1121.0     19357.0  19357.0
#  4      16288.0         1273.0     17561.0  17561.0
#  ..         ...            ...         ...      ...
#  100     4681.0         1139.0      5820.0   5820.0
#  101     4681.0         1139.0      5820.0   5820.0
#  102     4681.0         1139.0      5820.0   5820.0
#  103     4681.0         1139.0      5820.0   5820.0
#  104     4681.0         1139.0      5820.0   5820.0
#
#  [105 rows x 26 columns],
#  'N102':    Link no                                               Name   S_LRP  \
#  0   N102-1    Mainamati-Kangsanagar (Intersection with Z1219)    LRPS
#  1   N102-2  Kangsanagar (Int with Z1219)-Debidduar (Int wi...  LRP009
#  2   N102-3  Debiduar (Int with Z1008)- Companiganj (Int wi...  LRP018
#  3   N102-4  Companiganj (Int with Z1205) - Mirpur (Int wit...  LRP024
#  4   N102-5     Mirpur (Int with Z1041)- Kuti (Int with Z1201)  LRP038
#  5   N102-6   Kuti (Int with Z1201)- Dharkhar (Int with Z1202)  LRP042
#  6   N102-7  Dharkhar (Int with Z1202)-Sultanpur (Int with ...  LRP055
#  7   N102-8  Sultanpur (Int with Z1216)-Kuatali(Int. with N...  LRP062
#  8   N102-9   Kuatali(Int. with N103)-Gathuria(Int. with N103)  LRP070
#  9  N102-10  Gathuria(Int. with N103)-Sarail(Kathihat, int....  LRP070
#
#     S_Offset  S_Chainage   E_LRP  E_Offset  E_Chainage  Length (km)  \
#  0         0       0.000  LRP009      1110      10.206       10.206
#  1      1110      10.206  LRP018      2570      20.658       10.452
#  2      2570      20.658  LRP024      1242      25.473        4.815
#  3      1242      25.473  LRP038       408      38.866       13.393
#  4       408      38.866  LRP042      1928      44.427        5.561
#  5      1928      44.427  LRP055      1143      56.883       12.456
#  6      1143      56.883  LRP062       169      63.061        6.178
#  7       169      63.061  LRP070       419      71.456        8.395
#  8       419      71.456  LRP070      6234      77.271        5.815
#  9      6234      77.271    LRPE         0      83.382        6.111
#
#     Heavy Truck  ...    Car  Auto Rickshaw  Motor Cycle  Bi-Cycle  \
#  0        231.0  ...  164.0         5450.0        621.0     196.0
#  1        231.0  ...  164.0         5450.0        621.0     196.0
#  2        231.0  ...  164.0         5450.0        621.0     196.0
#  3        346.0  ...  231.0         2525.0        483.0     124.0
#  4        346.0  ...  231.0         2525.0        483.0     124.0
#  5        346.0  ...  231.0         2525.0        483.0     124.0
#  6        346.0  ...  231.0         2525.0        483.0     124.0
#  7         98.0  ...  512.0         5591.0        858.0     209.0
#  8         98.0  ...  512.0         5591.0        858.0     209.0
#  9         98.0  ...  512.0         5591.0        858.0     209.0
#
#     Cycle Rickshaw  Cart  Motorized  Non Motorized  Total AADT   (AADT)
#  0           413.0   0.0     9099.0          609.0      9708.0   9708.0
#  1           413.0   0.0     9099.0          609.0      9708.0   9708.0
#  2           413.0   0.0     9099.0          609.0      9708.0   9708.0
#  3           507.0   0.0     6046.0          631.0      6677.0   6677.0
#  4           507.0   0.0     6046.0          631.0      6677.0   6677.0
#  5           507.0   0.0     6046.0          631.0      6677.0   6677.0
#  6           507.0   0.0     6046.0          631.0      6677.0   6677.0
#  7          1041.0   0.0    11521.0         1250.0     12771.0  12771.0
#  8          1041.0   0.0    11521.0         1250.0     12771.0  12771.0
#  9          1041.0   0.0    11521.0         1250.0     12771.0  12771.0
#
#  [10 rows x 26 columns],
#  'N104':     Link no                                               Name   S_LRP  \
#  0    N104-1  Feni (Trank Road)-Feni (Mohipal Chourasta) Int...    LRPS
#  1    N104-2  Feni (Int. with N1)-Feni (Temohoni)Int.with Z1444    LRPS
#  2    N104-3  Feni (Temohoni)Int.with Z1444-Selonia (Int.wit...  LRP004
#  3    N104-4  Selonia(Int.with Z1443)-Daganbhuiyan (Int.with...  LRP008
#  4    N104-5  Daganbhuiyan (Int.with Z1441)-Tulatali (Int.wi...  LRP014
#  5    N104-6  Tulatali (Int.with Z1030)- Kallandi (Int.with ...  LRP017
#  6    N104-7  Kallandi (Int.with Z1421)-  Chowmohoni (Int.wi...  LRP023
#  7    N104-8  Chowmohoni (Int.with Z1420)-Chowmohoni (Int.wi...  LRP032
#  8    N104-9  Chowmohoni (Int.with R142 & R140)-Maijdee Baza...  LRP032
#  9   N104-10  Maijdee Bazar(Int.with R143)-Maijdee(Int.with ...  LRP042
#  10  N104-11                    Maijdee(Int.with Z1429)-Sonapur  LRP044
#
#      S_Offset  S_Chainage   E_LRP  E_Offset  E_Chainage  Length (km)  \
#  0          0       0.000    LRPS      1878       1.878        1.878
#  1       1878       1.878  LRP004       270       4.350        2.472
#  2        270       4.350  LRP008       485       8.315        3.965
#  3        485       8.315  LRP014       994      14.809        6.494
#  4        994      14.809  LRP017       230      17.130        2.321
#  5        230      17.130  LRP023       923      23.823        6.693
#  6        923      23.823  LRP032      2120      34.120       10.297
#  7       2120      34.120  LRP032      4033      36.033        1.913
#  8       4033      36.033  LRP042      1230      43.030        6.997
#  9       1230      43.030  LRP044      1380      45.200        2.170
#  10      1380      45.200    LRPE         0      49.630        4.430
#
#      Heavy Truck  ...    Car  Auto Rickshaw  Motor Cycle  Bi-Cycle  \
#  0          90.0  ...  174.0         4683.0        597.0     258.0
#  1          90.0  ...  174.0         4683.0        597.0     258.0
#  2          90.0  ...  174.0         4683.0        597.0     258.0
#  3          90.0  ...  174.0         4683.0        597.0     258.0
#  4          67.0  ...   90.0         4147.0        768.0     332.0
#  5          67.0  ...   90.0         4147.0        768.0     332.0
#  6          67.0  ...   90.0         4147.0        768.0     332.0
#  7          67.0  ...   90.0         4147.0        768.0     332.0
#  8          46.0  ...  357.0         3066.0       1066.0     270.0
#  9          46.0  ...  357.0         3066.0       1066.0     270.0
#  10         19.0  ...  393.0         3681.0       1025.0     446.0
#
#      Cycle Rickshaw  Cart  Motorized  Non Motorized  Total AADT  (AADT)
#  0           1328.0   0.0     7799.0         1586.0      9385.0  9385.0
#  1           1328.0   0.0     7799.0         1586.0      9385.0  9385.0
#  2           1328.0   0.0     7799.0         1586.0      9385.0  9385.0
#  3           1328.0   0.0     7799.0         1586.0      9385.0  9385.0
#  4           1228.0   8.0     7170.0         1568.0      8738.0  8738.0
#  5           1228.0   8.0     7170.0         1568.0      8738.0  8738.0
#  6           1228.0   8.0     7170.0         1568.0      8738.0  8738.0
#  7           1228.0   8.0     7170.0         1568.0      8738.0  8738.0
#  8            447.0   0.0     8865.0          717.0      9582.0  9582.0
#  9            447.0   0.0     8865.0          717.0      9582.0  9582.0
#  10           542.0   0.0     7898.0          988.0      8886.0  8886.0
#
#  [11 rows x 26 columns],
#  'N105':   Link no                                               Name    S_LRP  \
#  0  N105-1  Madanpur (13th km of N1)-Nayapur, Bostail (Int...     LRPS
#  1  N105-2  Nayapur, Bostail(Int.with R114)-Bhulta (Int.wi...   LRP006
#  2  N105-3                Bhulta (Int.with N2)-Purbachal Road   LRP012
#  3  N105-4          Purbachal Road- Ulukhola (Int.with Z3010)  LRP020d
#  4  N105-5  Ulukhola (Int.with Z3010)-Mirer Bazar (Int.wit...   LRP028
#  5  N105-6  Mirer Bazar (Int.with R301)-Vogra Bypass(Int.w...   LRP035
#  6  N105-7  Vogra Bypass(Int.with N3)-End of Road (Int.wit...   LRP045
#
#     S_Offset  S_Chainage    E_LRP  E_Offset  E_Chainage  Length (km)  \
#  0         0       0.000   LRP006       181       6.309        6.309
#  1       181       6.309   LRP012       546      12.803        6.494
#  2       546      12.803  LRP020d         0      21.221        8.418
#  3         0      21.221   LRP028       895      28.610        7.389
#  4       895      28.610   LRP035      1289      36.158        7.548
#  5      1289      36.158   LRP045      1118      45.998        9.840
#  6      1118      45.998     LRPE         0      48.881        2.883
#
#     Heavy Truck  ...     Car  Auto Rickshaw  Motor Cycle  Bi-Cycle  \
#  0        338.0  ...   619.0         5625.0        552.0     145.0
#  1        245.0  ...   954.0         2332.0        659.0     180.0
#  2        223.0  ...  1275.0         2563.0        484.0      64.0
#  3        320.0  ...   804.0         1144.0        622.0     102.0
#  4        320.0  ...   804.0         1144.0        622.0     102.0
#  5        320.0  ...   804.0         1144.0        622.0     102.0
#  6        328.0  ...  1240.0         1243.0        452.0     149.0
#
#     Cycle Rickshaw  Cart  Motorized  Non Motorized  Total AADT   (AADT)
#  0          1648.0   0.0    13111.0         1793.0     14904.0  14904.0
#  1          1011.0   0.0    10396.0         1191.0     11587.0  11587.0
#  2           249.0   0.0    11521.0          313.0     11834.0  11834.0
#  3           363.0   0.0     8791.0          465.0      9256.0   9256.0
#  4           363.0   0.0     8791.0          465.0      9256.0   9256.0
#  5           363.0   0.0     8791.0          465.0      9256.0   9256.0
#  6          1353.0   0.0    10373.0         1502.0     11875.0  11875.0
#
#  [7 rows x 26 columns],
#  'N106':   Link no                                               Name   S_LRP  \
#  0  N106-1  Chittagong (Oxygen More)-Hathazari (Int. with ...    LRPS
#  1  N106-2  Hathazari (Int. with R160)-Gohira(Int.with Z1619)  LRP010
#  2  N106-3  Gohira(Int.with Z1619)-Munshihat (Int.with Z1629)  LRP018
#  3  N106-4  Munshihat (Int.with Z1629)-Raozan (Int.with Z1...  LRP024
#  4  N106-5  Raozan (Int.with Z1012)-Ranirhat (Int.with Z1613)  LRP025
#  5  N106-6  Ranirhat (Int.with Z1613)-Gabtoli (Int.with Z1...  LRP039
#  6  N106-7   Gabtoli (Int.with Z1617)-Ghagra (Int. with R161)  LRP044
#  7  N106-8  Ghagra (Int. with R161)-Manikchhari(Int. with ...  LRP051
#  8  N106-9              Manikchhari(Int. with R162)-Rangamati  LRP059
#
#     S_Offset  S_Chainage   E_LRP  E_Offset  E_Chainage  Length (km)  \
#  0         0       0.000  LRP010      2084      12.192       12.192
#  1      2084      12.192  LRP018      1533      19.321        7.129
#  2      1533      19.321  LRP024       828      24.297        4.976
#  3       828      24.297  LRP025       820      25.278        0.981
#  4       820      25.278  LRP039       690      37.250       11.972
#  5       690      37.250  LRP044       296      41.825        4.575
#  6       296      41.825  LRP051       147      48.879        7.054
#  7       147      48.879  LRP059       566      57.303        8.424
#  8       566      57.303    LRPE         0      66.850        9.547
#
#     Heavy Truck  ...     Car  Auto Rickshaw  Motor Cycle  Bi-Cycle  \
#  0         12.0  ...  1063.0         8817.0       1355.0     234.0
#  1          0.0  ...   296.0         5481.0       1078.0     576.0
#  2          0.0  ...   296.0         5481.0       1078.0     576.0
#  3          0.0  ...   296.0         5481.0       1078.0     576.0
#  4          0.0  ...   103.0          520.0        372.0       0.0
#  5          0.0  ...   103.0          520.0        372.0       0.0
#  6          0.0  ...   103.0          520.0        372.0       0.0
#  7          0.0  ...    35.0          904.0        471.0       0.0
#  8          0.0  ...    35.0          904.0        471.0       0.0
#
#     Cycle Rickshaw  Cart  Motorized  Non Motorized  Total AADT   (AADT)
#  0           393.0   0.0    17165.0          627.0     17792.0  17792.0
#  1           943.0   0.0     8908.0         1519.0     10427.0  10427.0
#  2           943.0   0.0     8908.0         1519.0     10427.0  10427.0
#  3           943.0   0.0     8908.0         1519.0     10427.0  10427.0
#  4             0.0   0.0     2443.0            0.0      2443.0   2443.0
#  5             0.0   0.0     2443.0            0.0      2443.0   2443.0
#  6             0.0   0.0     2443.0            0.0      2443.0   2443.0
#  7             0.0   0.0     1975.0            0.0      1975.0   1975.0
#  8             0.0   0.0     1975.0            0.0      1975.0   1975.0
#
#  [9 rows x 26 columns],
#  'N2':    Link no                                               Name   S_LRP  \
#  0     N2-1                    Katchpur-Tarabo (Int with R201)    LRPS
#  1     N2-2  Tarabo(Int with R 201)-Barpa(Int. with Z1090 L...  LRP002
#  2     N2-3  Barpa(Int. with Z1090 LGED Road)-Bhulta (Int.w...  LRP006
#  3     N2-4      Bhulta (Int.with R202)-Bhulta (Int.with R203)  LRP011
#  4     N2-5   Bhulta (Int.with R203)-Panchdona (Int.with R301)  LRP011
#  5     N2-6               Panchdona-Shahepratap(Int.with R210)  LRP030
#  6     N2-7  Shahepratap(Int.with R210)-Itakhola(Int.with R...  LRP033
#  7     N2-8                   Itakhola-Morgal (Int.with Z2042)  LRP042
#  8     N2-9  Morgal (Int.with Z2042)-Narayanpur (Int.with Z...  LRP055
#  9    N2-10  Narayanpur (Int.with Z2032)-Bhairab (Int.with ...  LRP064
#  10   N2-11  Bhairab (Int.with R360)-Ashuganj (Int.with Z2031)  LRP069
#  11   N2-12  Ashuganj (Int.with Z2031)-Kathirhat, Sarail (I...  LRP069
#  12   N2-13  Kathirhat, Sarail (Int.with N102)-Sarail (Int....  LRP086
#  13   N2-14  Sarail (Int.with R220)-Jagadishpur(Int.with N204)  LRP086
#  14   N2-15  Jagadishpur(Int.with N204)-Shaistaganj (Int.wi...  LRP117
#  15   N2-16  Shaistaganj (Int.with N204)-Mirpur (Int.with N...  LRP142
#  16   N2-17    Mirpur (Int.with N207)-Auskandi (Int.with R240)  LRP146
#  17   N2-18  Auskandi (Int.with R240)-Auskandi (Int.with R241)  LRP182
#  18   N2-19   Auskandi (Int.with R241)-Sherpur (Int.with N207)  LRP186
#  19   N2-20     Sherpur (Int.with N207)-Tajpur(Int.with Z2022)  LRP191
#  20   N2-21   Tajpur(Int.with Z2022)-Rashidpur(Int.with Z2016)  LRP205
#  21   N2-22            Rashidpur(Int.with Z2016)-Int.with R283  LRP216
#  22   N2-23          Int.with R283-Chandipole (Int.with Z2013)  LRP224
#  23   N2-24  Chandipole (Int.with Z2013)-Mominkhola (Int.wi...  LRP225
#  24   N2-25  Mominkhola (Int.with N208)-Nayarpool(Int.with ...  LRP226
#  25   N2-26            Nayarpool(Int.with N206)-Int. with N210  LRP229
#  26   N2-27            Int. with N210-Darbast(Int. with Z2011)  LRP238
#  27   N2-28    Darbast(Int. with Z2011)-Tamabil(Int.with N212)  LRP263
#  28   N2-29                     Tamabil(Int.with N212)-Jaflong  LRP282
#
#      S_Offset  S_Chainage   E_LRP  E_Offset  E_Chainage  Length (km)  \
#  0          0       0.000  LRP002      1147       2.313        2.313
#  1       1147       2.313  LRP006       900       6.076        3.763
#  2        900       6.076  LRP011       915      11.111        5.035
#  3        915      11.111  LRP011      1781      11.977        0.866
#  4       1781      11.977  LRP030       999      30.225       18.248
#  5        999      30.225  LRP033      1280      33.536        3.311
#  6       1280      33.536  LRP042      1831      43.097        9.561
#  7       1831      43.097  LRP055       280      54.606       11.509
#  8        280      54.606  LRP064       621      63.969        9.363
#  9        621      63.969  LRP069      2478      70.576        6.607
#  10      2478      70.576  LRP069      5435      73.533        2.957
#  11      5435      73.533  LRP086       710      85.823       12.290
#  12       710      85.823  LRP086      1300      86.413        0.590
#  13      1300      86.413  LRP117       378     116.294       29.881
#  14       378     116.294  LRP142       278     141.309       25.015
#  15       278     141.309  LRP146       920     145.961        4.652
#  16       920     145.961  LRP182       527     181.657       35.696
#  17       527     181.657  LRP186       600     185.770        4.113
#  18       600     185.770  LRP191       672     190.892        5.122
#  19       672     190.892  LRP205       750     205.083       14.191
#  20       750     205.083  LRP216       414     215.832       10.749
#  21       414     215.832  LRP224       571     224.044        8.212
#  22       571     224.044  LRP225       900     225.373        1.329
#  23       900     225.373  LRP226      2264     227.757        2.384
#  24      2264     227.757  LRP229      2095     229.888        2.131
#  25      2095     229.888  LRP238      1040     237.923        8.035
#  26      1040     237.923  LRP263       129     262.122       24.199
#  27       129     262.122  LRP282      1155     282.098       19.976
#  28      1155     282.098  LRP287       578     286.516        4.418
#
#      Heavy Truck  ...     Car  Auto Rickshaw  Motor Cycle  Bi-Cycle  \
#  0         239.0  ...  3024.0         4643.0        567.0     409.0
#  1         227.0  ...  1458.0         3517.0        813.0     190.0
#  2         237.0  ...  1473.0         4094.0       1075.0     393.0
#  3         237.0  ...  1473.0         4094.0       1075.0     393.0
#  4         244.0  ...  1098.0         3128.0        899.0     218.0
#  5          70.0  ...  1392.0         2708.0       1305.0     304.0
#  6          70.0  ...  1392.0         2708.0       1305.0     304.0
#  7         201.0  ...   859.0         2158.0        387.0      52.0
#  8         436.0  ...   808.0         3037.0        610.0     153.0
#  9         436.0  ...   808.0         3037.0        610.0     153.0
#  10        436.0  ...   808.0         3037.0        610.0     153.0
#  11        329.0  ...   534.0         3351.0        690.0     389.0
#  12        205.0  ...   398.0         3816.0        331.0     164.0
#  13        205.0  ...   398.0         3816.0        331.0     164.0
#  14        270.0  ...   764.0         1170.0        493.0      53.0
#  15        206.0  ...  1159.0         1975.0        721.0     170.0
#  16        338.0  ...  1058.0         1784.0        325.0      68.0
#  17        338.0  ...  1058.0         1784.0        325.0      68.0
#  18        321.0  ...   621.0         1932.0        386.0     197.0
#  19        321.0  ...   621.0         1932.0        386.0     197.0
#  20        198.0  ...   991.0         3948.0        846.0     329.0
#  21        198.0  ...   991.0         3948.0        846.0     329.0
#  22         83.0  ...   356.0         3665.0        447.0     367.0
#  23         83.0  ...   356.0         3665.0        447.0     367.0
#  24         83.0  ...   356.0         3665.0        447.0     367.0
#  25        466.0  ...   337.0          653.0        525.0     139.0
#  26        466.0  ...   337.0          653.0        525.0     139.0
#  27        453.0  ...   335.0          874.0        372.0     203.0
#  28        462.0  ...   318.0          753.0        412.0     186.0
#
#      Cycle Rickshaw  Cart  Motorized  Non Motorized  Total AADT   (AADT)
#  0            942.0   0.0    23308.0         1351.0     24659.0  24659.0
#  1            522.0   0.0    17245.0          712.0     17957.0  17957.0
#  2           3205.0   0.0    17748.0         3598.0     21346.0  21346.0
#  3           3205.0   0.0    17748.0         3598.0     21346.0  21346.0
#  4           1142.0   0.0    11243.0         1360.0     12603.0  12603.0
#  5            651.0   0.0    12226.0          955.0     13181.0  13181.0
#  6            651.0   0.0    12226.0          955.0     13181.0  13181.0
#  7             64.0   0.0     9891.0          116.0     10007.0  10007.0
#  8            489.0   0.0    11151.0          642.0     11793.0  11793.0
#  9            489.0   0.0    11151.0          642.0     11793.0  11793.0
#  10           489.0   0.0    11151.0          642.0     11793.0  11793.0
#  11           843.0   0.0     9383.0         1232.0     10615.0  10615.0
#  12           443.0   0.0    11039.0          607.0     11646.0  11646.0
#  13           443.0   0.0    11039.0          607.0     11646.0  11646.0
#  14            79.0   0.0     8071.0          132.0      8203.0   8203.0
#  15           415.0   0.0    12680.0          585.0     13265.0  13265.0
#  16           162.0  33.0     7229.0          263.0      7492.0   7492.0
#  17           162.0  33.0     7229.0          263.0      7492.0   7492.0
#  18           353.0   6.0     6524.0          556.0      7080.0   7080.0
#  19           353.0   6.0     6524.0          556.0      7080.0   7080.0
#  20           546.0   0.0    10814.0          875.0     11689.0  11689.0
#  21           546.0   0.0    10814.0          875.0     11689.0  11689.0
#  22           579.0   0.0     7634.0          946.0      8580.0   8580.0
#  23           579.0   0.0     7634.0          946.0      8580.0   8580.0
#  24           579.0   0.0     7634.0          946.0      8580.0   8580.0
#  25           328.0   0.0     5093.0          467.0      5560.0   5560.0
#  26           328.0   0.0     5093.0          467.0      5560.0   5560.0
#  27           356.0   0.0     5108.0          559.0      5667.0   5667.0
#  28           311.0   0.0     4743.0          497.0      5240.0   5240.0
#
#  [29 rows x 26 columns],
#  'N204':   Link no                                       Name   S_LRP  S_Offset  \
#  0  N204-1   Jagadishpur-Chunarughat (Int.with Z2008)    LRPS         0
#  1  N204-2  Chunarughat (Int.with Z2008)-Shaisthaganj  LRP022      5439
#
#     S_Chainage   E_LRP  E_Offset  E_Chainage  Length (km)  Heavy Truck  ...  \
#  0       0.000  LRP022      5439      25.449       25.449          0.0  ...
#  1      25.449    LRPE         0      34.421        8.972          0.0  ...
#
#      Car  Auto Rickshaw  Motor Cycle  Bi-Cycle  Cycle Rickshaw  Cart  \
#  0  92.0         1119.0        378.0     127.0           230.0   0.0
#  1  92.0         1119.0        378.0     127.0           230.0   0.0
#
#     Motorized  Non Motorized  Total AADT  (AADT)
#  0     2271.0          357.0      2628.0  2628.0
#  1     2271.0          357.0      2628.0  2628.0
#
#  [2 rows x 26 columns],
#  'N207':   Link no                                               Name   S_LRP  \
#  0  N207-1                Mirpur-Natun Bazar (Int.with Z2008)    LRPS
#  1  N207-2  Natun Bazar (Int.with Z2008)-Srimongal  (Int.w...  LRP001
#  2  N207-3  Srimongal (Int.with Z2003)-Moulvibazar (Int.wi...  LRP024
#  3  N207-4                Moulvibazar (Int.with N208)-Sherpur  LRP043
#
#     S_Offset  S_Chainage   E_LRP  E_Offset  E_Chainage  Length (km)  \
#  0         0       0.000  LRP001      1990       2.990        2.990
#  1      1990       2.990  LRP024       464      24.319       21.329
#  2       464      24.319  LRP043        12      42.917       18.598
#  3        12      42.917    LRPE         0      67.985       25.068
#
#     Heavy Truck  ...    Car  Auto Rickshaw  Motor Cycle  Bi-Cycle  \
#  0         31.0  ...  386.0         2594.0        467.0     141.0
#  1         31.0  ...  386.0         2594.0        467.0     141.0
#  2         31.0  ...  386.0         2594.0        467.0     141.0
#  3         31.0  ...  386.0         2594.0        467.0     141.0
#
#     Cycle Rickshaw  Cart  Motorized  Non Motorized  Total AADT  (AADT)
#  0           150.0   0.0     5038.0          291.0      5329.0  5329.0
#  1           150.0   0.0     5038.0          291.0      5329.0  5329.0
#  2           150.0   0.0     5038.0          291.0      5329.0  5329.0
#  3           150.0   0.0     5038.0          291.0      5329.0  5329.0
#
#  [4 rows x 26 columns],
#  'N208':   Link no                                               Name   S_LRP  \
#  0  N208-1                         Moulvibazar-Int.with Z2002    LRPS
#  1  N208-2            Int.with Z2002-Rajnagar (Int.with R281)    LRPS
#  2  N208-3  Rajnagar(Int.with R281)-Daudabad (Int.with Z2832)  LRP012
#  3  N208-4  Daudabad (Int.with Z2832)-Royal City Chottor(i...  LRP052
#  4  N208-5      Royal City Chottor(int.with N210)-Int.with N2  LRP054
#
#     S_Offset  S_Chainage   E_LRP  E_Offset  E_Chainage  Length (km)  \
#  0         0       0.000    LRPS      3190       3.190        3.190
#  1      3190       3.190  LRP012      1661      13.461       10.271
#  2      1661      13.461  LRP052       385      51.050       37.589
#  3       385      51.050  LRP054       677      53.342        2.292
#  4       677      53.342  LRP058       900      57.495        4.153
#
#     Heavy Truck  ...    Car  Auto Rickshaw  Motor Cycle  Bi-Cycle  \
#  0         15.0  ...  741.0         3194.0       1123.0     147.0
#  1         15.0  ...  741.0         3194.0       1123.0     147.0
#  2          0.0  ...  811.0         2233.0        582.0      88.0
#  3          0.0  ...  811.0         2233.0        582.0      88.0
#  4         39.0  ...  778.0         2974.0       1231.0     695.0
#
#     Cycle Rickshaw  Cart  Motorized  Non Motorized  Total AADT   (AADT)
#  0           486.0   0.0     7514.0          633.0      8147.0   8147.0
#  1           486.0   0.0     7514.0          633.0      8147.0   8147.0
#  2            73.0   0.0     5328.0          161.0      5489.0   5489.0
#  3            73.0   0.0     5328.0          161.0      5489.0   5489.0
#  4           822.0  47.0     9488.0         1564.0     11052.0  11052.0
#
#  [5 rows x 26 columns]}

# %% [markdown]
# # Clean

# %%
traffic_data_cleaned = {}

for road in traffic_data.keys():
    df_road = traffic_data[road].copy()  # Create a copy to avoid modifying the original DataFrame

    # if df_road['Link no'] has 'R' at the end, drop rows
    df_road = df_road[~df_road['Link no'].str.endswith('R')]

    # if df_road['Link no'] has 'L' at the end, remove 'L' from the end
    df_road.loc[:, 'Link no'] = df_road['Link no'].str.replace('L', '', regex=False)

    # Duplicate the column 'Link no' to 'Road' and insert it as the first column
    df_road.insert(0, 'Road', df_road['Link no'])

    # 'Link no' column --> split the string by '-' and take the last part
    df_road.loc[:, 'Link no'] = df_road['Link no'].str.split('-').str[-1]

    # 'Road' column --> split the string by '-' and take the first part
    df_road.loc[:, 'Road'] = df_road['Road'].str.split('-').str[0]

    # Remove duplicated rows based on 'S_Chainage' and 'E_Chainage' columns
    df_road = df_road.drop_duplicates(subset=['S_Chainage', 'E_Chainage'], keep='last')

    # Remove rows where 'S_Chainage' and 'E_Chainage' are the same
    df_road = df_road[df_road['S_Chainage'] != df_road['E_Chainage']]

    # Save the cleaned DataFrame to the dictionary
    traffic_data_cleaned[road] = df_road

    # Save the cleaned data to CSV files
    file_path = '../data/processed/'
    cleaned_file_name = f"{file_path + road + '_traffic_cleaned'}.csv"
    df_road.to_csv(cleaned_file_name, index=False)

# %%
traffic_data_cleaned['N1']
# Out:
#     Road Link no                                           Name   S_LRP  \
# 0     N1       1       Jatrabari - Int.with Z1101 (Left) (Left)    LRPS
# 2     N1       2  Int.with Z1101 - Signboard (Left) R111 (Left)    LRPS
# 4     N1       3         Signboard - Shimrail (Left)R110 (Left)    LRPS
# 6     N1       4          Shimrail  - Katchpur  (Left)N2 (Left)    LRPS
# 8     N1       5          Katchpur - Madanpur (Left)N105 (Left)  LRP009
# ..   ...     ...                                            ...     ...
# 100   N1      65         Coxsbazar Link Road N110-Maricha Z1009  LRP386
# 101   N1      66            Maricha Z1009-Ukhia Dakbanglo Z1503  LRP403
# 102   N1      67           Ukhia Dakbanglo Z1503 - Gundum Z1504  LRP413
# 103   N1      68             GundumGundum Z1504 - Whykong Z1133  LRP420
# 104   N1      69                         Whykong Z1133 - Teknaf  LRP433
#
#      S_Offset  S_Chainage   E_LRP  E_Offset  E_Chainage  Length (km)  ...  \
# 0           0       0.000    LRPS       822       0.822        0.822  ...
# 2         822       0.822    LRPS      4175       4.175        3.353  ...
# 4        4175       4.175    LRPS      7181       7.181        3.006  ...
# 6        7181       7.181  LRP009       260       8.763        1.582  ...
# 8         260       8.763  LRP012       439      11.936        3.173  ...
# ..        ...         ...     ...       ...         ...          ...  ...
# 100       724     381.481  LRP403       217     398.205       16.724  ...
# 101       217     398.205  LRP413       300     408.434       10.229  ...
# 102       300     408.434  LRP420       900     416.044        7.610  ...
# 103       900     416.044  LRP433       521     428.908       12.864  ...
# 104       521     428.908  LRP467       130     462.254       33.346  ...
#
#         Car  Auto Rickshaw  Motor Cycle  Bi-Cycle  Cycle Rickshaw  Cart  \
# 0    1851.0         2980.0        398.0     232.0           889.0   0.0
# 2    2608.0         2508.0        436.0     213.0          1088.0   0.0
# 4    1690.0         2266.0       1087.0      75.0          1198.0   0.0
# 6    1579.0         3154.0       1162.0     211.0          1077.0   0.0
# 8    1579.0         3154.0       1154.0     211.0          1077.0   0.0
# ..      ...            ...          ...       ...             ...   ...
# 100   142.0         2476.0        419.0      97.0          1042.0   0.0
# 101   142.0         2476.0        419.0      97.0          1042.0   0.0
# 102   142.0         2476.0        419.0      97.0          1042.0   0.0
# 103   142.0         2476.0        419.0      97.0          1042.0   0.0
# 104   142.0         2476.0        419.0      97.0          1042.0   0.0
#
#      Motorized  Non Motorized  Total AADT   (AADT)
# 0      18236.0         1121.0     19357.0  19357.0
# 2      20236.0         1301.0     21537.0  21537.0
# 4      16288.0         1273.0     17561.0  17561.0
# 6      16001.0         1288.0     17289.0  17289.0
# 8      22591.0         1288.0     23879.0  23879.0
# ..         ...            ...         ...      ...
# 100     4681.0         1139.0      5820.0   5820.0
# 101     4681.0         1139.0      5820.0   5820.0
# 102     4681.0         1139.0      5820.0   5820.0
# 103     4681.0         1139.0      5820.0   5820.0
# 104     4681.0         1139.0      5820.0   5820.0
#
# [69 rows x 27 columns]
